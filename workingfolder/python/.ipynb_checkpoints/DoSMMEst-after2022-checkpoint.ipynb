# %% [markdown]
# ## SMM Estimation of Theories of Expectation Formation with Inflation Expectation

# %%
import numpy as np
import matplotlib.pyplot as plt
from numba import types
from numba.typed import Dict,List
import pandas as pd
from statsmodels.tsa.api import AutoReg as AR
pd.options.display.float_format = '{:,.2f}'.format
plt.style.use('ggplot')

## figure config

lw = 4  #line width

# %% [markdown]
# ## Model

# %%
from SMMEst import SimAR1, SimUCSV,ObjGen, ObjWeight,ParaEst,type_list

from SMMEst import StickyExpectationAR, StickyExpectationSV
from SMMEst import NoisyInformationAR, NoisyInformationSV
from SMMEst import DiagnosticExpectationAR, DiagnosticExpectationSV
from SMMEst import DENIHybridAR, DENIHybridSV

# %%
## create some fake parameters and data to initialize model class
### not used for estimation

## AR1 parameters
ρ0,σ0 = 0.98, 0.10

history0 = SimAR1(ρ0,
                  σ0,
                  200)
real_time0 = history0[11:-2]

realized0 = history0[12:-1]

### UCSV inflation

p0_fake = 0 ## initial permanent component
γ_fake = 0.1 ## size of shock to the volatility
σs_now_fake = [0.2,0.3] ## volatility of permanent and transitory component

ucsv_fake = SimUCSV(γ_fake,
                    nobs = 200,
                    p0 = p0_fake,
                    )

xx_real_time,xx_p_real_time,vol_p_real_time,vol_t_real_time = ucsv_fake

xx_realized = xx_real_time[1:-1]

xx_real_time= np.array([xx_real_time,
                        xx_p_real_time,
                        vol_p_real_time,
                        vol_t_real_time]
                      )[:,0:-2]

# %% [markdown]
# ### Sticky Expectation (SE) + AR1

# %% [markdown]
# ### Sticky Expectation (SE) + SV

# %%
## initialize the ar instance
sear0 = StickyExpectationAR(exp_para = np.array([0.2]),
                            process_para = np.array([ρ0,σ0]),
                            real_time = real_time0,
                            history = history0,
                            horizon = 1)

sear0.GetRealization(realized0)

# %%
## initialize the sv instance
sesv0 = StickyExpectationSV(exp_para = np.array([0.3]),
                           process_para = np.array([0.1]),
                           real_time = xx_real_time,
                           history = xx_real_time) ## history does not matter here, 

## get the realization 

sesv0.GetRealization(xx_realized)

# %% [markdown]
# ### Noisy Information (NI) + AR1

# %% [markdown]
# ### Noisy Information (NI) + SV

# %%
## initialize the ar instance
niar0 = NoisyInformationAR(exp_para = np.array([0.1,0.2]),
                            process_para = np.array([ρ0,σ0]),
                            real_time = real_time0,
                            history = history0,
                            horizon = 1)

niar0.GetRealization(realized0)

# %%
## initial a sv instance
nisv0 = NoisyInformationSV(exp_para = np.array([0.3,0.2]),
                           process_para = np.array([0.1]),
                           real_time = xx_real_time,
                           history = xx_real_time) ## history does not matter here, 

## get the realization 

nisv0.GetRealization(xx_realized)

# %% [markdown]
# ###  Diagnostic Expectation(DE) + AR1

# %% [markdown]
# ###  Diagnostic Expectation(DE) + SV

# %%
## initialize the ar instance
dear0 = DiagnosticExpectationAR(exp_para = np.array([0.5,0.2]),
                                process_para = np.array([ρ0,σ0]),
                                real_time = real_time0,
                                history = history0,
                                horizon = 1)

dear0.GetRealization(realized0)

# %%
## initial a sv instance
desv0 = DiagnosticExpectationSV(exp_para = np.array([0.3,0.2]),
                               process_para = np.array([0.1]),
                               real_time = xx_real_time,
                               history = xx_real_time) ## history does not matter here, 

## get the realization 

desv0.GetRealization(xx_realized)

# %% [markdown]
# ###  Diagnostic Expectation and Noisy Information Hybrid(DENI) + AR1

# %% [markdown]
# ###  Diagnostic Expectation and Noisy Information Hybrid(DENI) + SV

# %%
## initialize the ar instance
deniar0 = DENIHybridAR(exp_para = np.array([0.1,0.3]),
                       process_para = np.array([ρ0,σ0]),
                            real_time = real_time0,
                            history = history0,
                            horizon = 1)

deniar0.GetRealization(realized0)

# %%
## initial a sv instance
denisv0 = DENIHybridSV(exp_para = np.array([0.1,0.2]),
                           process_para = np.array([0.1]),
                           real_time = xx_real_time,
                           history = xx_real_time) ## history does not matter here, 

## get the realization 

denisv0.GetRealization(xx_realized)

# %% [markdown]
# ## Data Estimation

# %% [markdown]
# ### Prepare the data

# %% [markdown]
# #### Real-time Inflation data

# %%
import pandas as pd
real_time_index = pd.read_excel('../OtherData/RealTimeData/RealTimeInfQ.xlsx')

real_time_index.index = pd.to_datetime(real_time_index['DATE'],format='%Y%m%d')
real_time_index = real_time_index.drop(columns=['DATE'])

## turn index into yearly inflation
#real_time_index = pd.concat([real_time_cpic,real_time_cpi], join='inner', axis=1)
real_time_index.columns=['RTCPI','RTCPICore']
real_time_inf = real_time_index.pct_change(periods=12)*100  ## year-over-year inflation, standard 
real_time_inf = real_time_inf.dropna()

# %% [markdown]
# #### Inflation data

# %%
###############
## monthly ### 
##############

InfM = pd.read_stata('../OtherData/InfM.dta')
InfM = InfM[-InfM.date.isnull()]
dateM = pd.to_datetime(InfM['date'],format='%Y%m%d')

InfM.index = pd.DatetimeIndex(dateM,
                              freq='infer')

###############
## quarterly ##
###############

InfQ = InfM.resample('Q').last()
dateQ = pd.to_datetime(InfQ['date'],format='%Y%m%d')

dateQ_str = dateQ.dt.year.astype(int).astype(str) + \
             "Q" + dateQ.dt.quarter.astype(int).astype(str)

InfQ.index = pd.DatetimeIndex(dateQ_str,freq='infer')

###########################
#keep only needed variables 
############################

InfM = InfM[['Inf1y_CPIAU',
             'Inf1yf_CPIAU']]

InfQ = InfQ[['Inf1y_CPICore',
            'Inf1yf_CPICore']]

# %% [markdown]
# #### Expectation data

# %%
## expectation data from SPF 

PopQ = pd.read_stata('../SurveyData/InfExpQ.dta')  
PopQ = PopQ[-PopQ.date.isnull()]
dateQ = pd.to_datetime(PopQ['date'],format='%Y%m%d')
dateQ_str = dateQ.dt.year.astype(int).astype(str) + \
             "Q" + dateQ.dt.quarter.astype(int).astype(str)
PopQ.index = pd.DatetimeIndex(dateQ_str)
SPFCPI = PopQ[['SPFCPI_Mean','SPFCPI_FE','SPFCPI_Disg','SPFCPI_Var']].dropna(how='any')

## expectation data from SCE
PopM = pd.read_stata('../SurveyData/InfExpM.dta')
PopM = PopM[-PopM.date.isnull()]
dateM = pd.to_datetime(PopM['date'],format='%Y%m%d')
dateM_str = dateM.dt.year.astype(int).astype(str) + \
             "M" + dateM.dt.month.astype(int).astype(str)
PopM.index = pd.DatetimeIndex(dateM)

SCECPI = PopM[['SCE_Mean','SCE_FE','SCE_Disg','SCE_Var',
              'SCE_Mean_rd','SCE_FE_rd','SCE_Disg_rd','SCE_Var_rd']].dropna(how='any')

# %%
## plot times eries of 

SPFCPI.plot(title='SPF Expectations')

SCECPI.plot(title='SCE Expectations')
# Out:
# <AxesSubplot:title={'center':'SCE Expectations'}, xlabel='date'>

# %%
import datetime

## tempoary date used to check the data moments 

end_date_late = datetime.datetime(2023, 3, 30)
end_date_early = datetime.datetime(2020, 3, 30)

## we only focus on 4th quarter observations from SPF 
SPFCPI = SPFCPI[SPFCPI.index.quarter==4]

# %%
print('SCE\n')
print(SCECPI.mean())
print('sample period, begin at '+str(SCECPI.index[0])+', and end at '+str(SCECPI.index[-1]))
print('\n')
print('before 2020\n')
print(SCECPI[SCECPI.index<end_date_early].mean())

print('\n')

print('SPF (only in the forth quarter)\n')
print(SPFCPI.mean())
print('sample period, begin at '+str(SPFCPI.index[0])+', and end at '+str(SPFCPI.index[-1]))
print('\n')

print('before 2020\n')
print(SPFCPI[SPFCPI.index<end_date_early].mean())
# Out:
# SCE
#
# SCE_Mean       3.62
# SCE_FE         0.86
# SCE_Disg       7.46
# SCE_Var       10.55
# SCE_Mean_rd    0.01
# SCE_FE_rd     -0.00
# SCE_Disg_rd    3.04
# SCE_Var_rd     1.73
# dtype: float64
# sample period, begin at 2013-06-01 00:00:00, and end at 2022-06-01 00:00:00
#
#
# before 2020
#
# SCE_Mean       3.34
# SCE_FE         1.81
# SCE_Disg       6.85
# SCE_Var        9.64
# SCE_Mean_rd   -0.01
# SCE_FE_rd      0.06
# SCE_Disg_rd    2.81
# SCE_Var_rd     1.75
# dtype: float64
#
#
# SPF (only in the forth quarter)
#
# SPFCPI_Mean    2.02
# SPFCPI_FE     -0.32
# SPFCPI_Disg    0.18
# SPFCPI_Var     0.22
# dtype: float64
# sample period, begin at 2007-10-01 00:00:00, and end at 2021-10-01 00:00:00
#
#
# before 2020
#
# SPFCPI_Mean   1.97
# SPFCPI_FE     0.12
# SPFCPI_Disg   0.16
# SPFCPI_Var    0.21
# dtype: float64

# %%
## filter sample period 

## SPF
SPFCPI = SPFCPI[SPFCPI.index<end_date_early]

## SCE
SCECPI = SCECPI[SCECPI.index<end_date_early]

# %%
## Combine expectation data and real-time data 

SPF_est= pd.concat([SPFCPI,
                    real_time_inf,
                    InfQ], 
                   join='inner', 
                   axis=1)

SCE_est = pd.concat([SCECPI,
                     real_time_inf,
                     InfM], 
                    join='inner', 
                    axis=1)

# %% [markdown]
# #### History data

# %%
## process parameters estimation AR1 
# period filter 
start_t='2000-01-01'
end_t = '2023-3-30'   ## 

######################
### quarterly data ##
#####################

CPICQ = InfQ['Inf1y_CPICore'].copy().loc[start_t:end_t]

print('for SPF moments estimation, the sample is between '+str(start_t)+' and '+str(end_t))

###################
### monthly data ##
###################

CPIM = InfM['Inf1y_CPIAU'].copy().loc[start_t:end_t]

print('for SPF moments estimation, the sample is between '+str(start_t)+' and '+str(end_t))
# Out:
# for SPF moments estimation, the sample is between 2000-01-01 and 2023-3-30
# for SPF moments estimation, the sample is between 2000-01-01 and 2023-3-30

# %%
## history data, the series ends at the same dates with real-time data but startes earlier

st_t_history = '2000-01-01'
ed_t_SPF = SPF_est.index[-1].strftime('%Y%m%d')
ed_t_SCE = SCE_est.index[-1].strftime('%Y-%m-%d')

## get the quarterly index 
indexQ = CPICQ.index

## get history data quarterly and monthly respectively 
af = indexQ >= st_t_history 
bf = indexQ <=ed_t_SPF
time_filter = np.logical_and(af,bf)
time_filter_idx = indexQ[time_filter]

historyQ = real_time_inf.loc[time_filter_idx]
historyM = real_time_inf.loc[st_t_history:ed_t_SCE]

# %% [markdown]
# #### Realization data

# %%
## realized 1-year-ahead inflation

realized_CPIC = np.array(SPF_est['Inf1yf_CPICore']) 
realized_CPI = np.array(SCE_est['Inf1yf_CPIAU'])

# %% [markdown]
# #### AR1 parameters

# %%
######################
### quarterly data ##
#####################

CPICQ_demean = CPICQ

ARmodel = AR(CPICQ_demean,lags=[1],trend='n') 
ar_rs = ARmodel.fit()
rhoQ_est = ar_rs.params[0]
if rhoQ_est>1.0:
    rhoQ_est = 1.0
sigmaQ_est = np.sqrt(ar_rs.sigma2) #np.sqrt(sum(ar_rs.resid**2)/(len(CPIM)-1))

###################
### monthly data ##
###################

CPIM_demean = CPIM
ARmodel2 = AR(CPIM_demean,lags=[1],trend='n') ## 12 months of lags!
ar_rs2 = ARmodel2.fit()
rhoM_est = ar_rs2.params[0]
if rhoM_est>1.0:
    rhoM_est = 1.0
sigmaM_est = np.sqrt(ar_rs2.sigma2)  # or np.sqrt(sum(ar_rs2.resid**2)/(len(CPIM)-1))

# %%
print('For the sample before', str(end_t))

print('quarterly AR(1) estimates for CPI core:')
print(rhoQ_est)
print(sigmaQ_est)
print('monthly AR(1) estimates for CPI headline:')
print(rhoM_est)
print(sigmaM_est)
# Out:
# For the sample before 2023-3-30
# quarterly AR(1) estimates for CPI core:
# 1.0
# 0.44451310745382244
# monthly AR(1) estimates for CPI headline:
# 0.9921118128971833
# 0.4609866905739363

# %% [markdown]
# #### Data moments

# %%
#####################################
## preparing data moments
#####################################

## Be careful with the frequency here when computing auto-correlation!!!!!
### SPF: quarters 
### SCE: month

#####################
## Professionals ####
#####################

### inflation moments 

realized_CPIC = realized_CPIC[~np.isnan(realized_CPIC)]
InfAV_data = np.mean(realized_CPIC-np.mean(realized_CPIC))
InfVar_data = np.var(realized_CPIC)
InfATV_data = np.cov(np.stack( (realized_CPIC[1:],realized_CPIC[:-1]),axis = 0 ))[0,1]
## annual autocovariance

### expectation moments 
exp_data_SPF = SPF_est[['SPFCPI_Mean','SPFCPI_FE','SPFCPI_Disg','SPFCPI_Var']]
exp_data_SPF = exp_data_SPF.rename(columns={"SPFCPI_Mean": "Forecast", "SPFCPI_FE": "FE",
                            "SPFCPI_Disg":"Disg","SPFCPI_Var":"Var"})

FEs_data = exp_data_SPF['FE']
Disgs_data = exp_data_SPF['Disg']
Vars_data = exp_data_SPF['Var']

FE_data = np.mean(FEs_data)
FEVar_data = np.var(FEs_data)
FEATV_data = np.cov(np.stack( (FEs_data[1:],FEs_data[:-1]),axis = 0))[0,1]  ## one quarter apart 
## annual autocovariance


Disg_data = np.mean(Disgs_data)
DisgVar_data = np.var(Disgs_data)
DisgATV_data = np.cov(np.stack( (Disgs_data[1:],Disgs_data[:-1]),axis = 0))[0,1]
Var_data = np.mean(Vars_data)
VarVar_data = np.var(Vars_data)
VarATV_data = np.cov(np.stack( (Vars_data[1:],Vars_data[:-1]),axis = 0))[0,1]
## annual autocovariance



data_moms_dct_SPF = Dict.empty(
    key_type=types.unicode_type,
    value_type=types.float64,
)
data_moms_dct_SPF['InfAV'] = InfAV_data
data_moms_dct_SPF['InfVar'] = InfVar_data
data_moms_dct_SPF['InfATV'] = InfATV_data

data_moms_dct_SPF['FE'] = FE_data
data_moms_dct_SPF['FEVar'] = FEVar_data
data_moms_dct_SPF['FEATV'] = FEATV_data
data_moms_dct_SPF['Disg'] = Disg_data
data_moms_dct_SPF['DisgVar'] = DisgVar_data
data_moms_dct_SPF['DisgATV'] = DisgATV_data
data_moms_dct_SPF['Var'] = Var_data
data_moms_dct_SPF['VarVar'] = VarVar_data
data_moms_dct_SPF['VarATV'] = VarATV_data


##########################
### For households 
##########################

#############################################################################################
############!!!!! using "xx_rd" moments only if one wants to control for individual fixed effects
###########################################################################################

control_ind_fe = True

if control_ind_fe:
    exp_data_SCE = SCE_est[['SCE_Mean','SCE_FE','SCE_Disg_rd','SCE_Var_rd']]
    exp_data_SCE = exp_data_SCE.rename(columns={"SCE_Mean": "Forecast", "SCE_FE": "FE",
                                            "SCE_Disg_rd":"Disg","SCE_Var_rd":"Var"})
else:
    exp_data_SCE = SCE_est[['SCE_Mean','SCE_FE','SCE_Disg','SCE_Var']]
    exp_data_SCE = exp_data_SCE.rename(columns={"SCE_Mean": "Forecast", "SCE_FE": "FE",
                                            "SCE_Disg":"Disg","SCE_Var":"Var"})

## inflation moments 

realized_CPI = realized_CPI[~np.isnan(realized_CPI)]

InfAV_data = np.mean(realized_CPI-np.mean(realized_CPI))
InfVar_data = np.var(realized_CPI)
InfATV_data = np.cov(np.stack( (realized_CPI[1:],realized_CPI[:-1]),axis = 0 ))[0,1]

## expectation moments 
FEs_data = exp_data_SCE['FE']
Disgs_data = exp_data_SCE['Disg']
Vars_data = exp_data_SCE['Var']

FE_data = np.mean(FEs_data)
FEVar_data = np.var(FEs_data)
FEATV_data = np.cov(np.stack( (FEs_data[1:],FEs_data[:-1]),axis = 0 ))[0,1]

Disg_data = np.mean(Disgs_data)
DisgVar_data = np.var(Disgs_data)
DisgATV_data = np.cov(np.stack( (Disgs_data[1:],Disgs_data[:-1]),axis = 0))[0,1]
Var_data = np.mean(Vars_data)
VarVar_data = np.var(Vars_data)
VarATV_data = np.cov(np.stack( (Vars_data[1:],Vars_data[:-1]),axis = 0))[0,1]


data_moms_dct_SCE = Dict.empty(
    key_type=types.unicode_type,
    value_type=types.float64,
)
data_moms_dct_SCE['InfAV'] = InfAV_data
data_moms_dct_SCE['InfVar'] = InfVar_data
data_moms_dct_SCE['InfATV'] = InfATV_data
data_moms_dct_SCE['FE'] = FE_data
data_moms_dct_SCE['FEVar'] = FEVar_data
data_moms_dct_SCE['FEATV'] = FEATV_data
data_moms_dct_SCE['Disg'] = Disg_data
data_moms_dct_SCE['DisgVar'] = DisgVar_data
data_moms_dct_SCE['DisgATV'] = DisgATV_data
data_moms_dct_SCE['Var'] = Var_data
data_moms_dct_SCE['VarVar'] = VarVar_data
data_moms_dct_SCE['VarATV'] = VarATV_data

############# need to compute the unconditional moments here

# %%
print('SPF\n')
print(dict(data_moms_dct_SPF))
print('\n')
print('SCE\n')
print(dict(data_moms_dct_SCE))
# Out:
# SPF
#
# {'InfAV': 1.0086939994380373e-07, 'InfVar': 0.17017723619937897, 'InfATV': -0.035672946365319515, 'FE': 0.12488741427659988, 'FEVar': 0.13613413274288177, 'FEATV': -0.0505739596773157, 'Disg': 0.16117419302463531, 'DisgVar': 0.018073327839374542, 'DisgATV': 0.012411878644727953, 'Var': 0.21303563107977663, 'VarVar': 0.00029486240333176323, 'VarATV': 0.0001542924079860046}
#
#
# SCE
#
# {'InfAV': 4.361315308898384e-09, 'InfVar': 0.6527659893035889, 'InfATV': 0.6088165481962264, 'FE': 1.8118985891342163, 'FEVar': 0.9346376657485962, 'FEATV': 0.8915628470580675, 'Disg': 2.8054120540618896, 'DisgVar': 0.08537419885396957, 'DisgATV': 0.02641061173996643, 'Var': 1.7492247819900513, 'VarVar': 0.02738690935075283, 'VarATV': 0.002872353202983449}

# %% [markdown]
# #### model moments

# %%
fire_ar_mom_dct = {'InfAV':0.0,
           'InfVar':r'$\sigma^2_\omega/(1-\rho^2)$',
           'InfATV':r'$\rho\sigma^2_\omega/(1-\rho^2)$',
           'FE':0.0,
           'FEVar':r'$\sigma^2_\omega$',
           'FEATV':0.0,
           'Disg':0.0,
           'DisgVar':0.0,
           'DisgATV':0.0,
           'Var':r'$\sigma^2_\omega$',
            'VarVar':0.0,
            'VarATV':0.0
           }

fire_ar_mom = pd.DataFrame([dict(fire_ar_mom_dct)])
fire_ar_mom.index = ['FIRE+AR']


fire_sv_mom_dct = {'InfAV':0.0,
           'InfVar':'N/A',
           'InfATV':'N/A',
           'FE':0.0,
           'FEVar':r'$\bar\sigma^2_{\eta}+\bar\sigma^2_{z}$',
           'FEATV':0.0,
           'Disg':0.0,
           'DisgVar':0.0,
           'DisgATV':0.0,
           'Var':r'$\bar\sigma^2_{\eta}+\bar\sigma^2_{z}$',
            'VarVar':'>0',
            'VarATV':'>0'
           }

fire_sv_mom = pd.DataFrame([dict(fire_sv_mom_dct)])
fire_sv_mom.index = ['FIRE+SV']


## these moments have not been used yet 
## need to make sure all is correct 

sear_mom_dct = {'InfAV':0.0,
           'InfVar':r'$\sigma^2_\omega/(1-\rho^2)$',
           'InfATV':r'$\rho\sigma^2\omega/(1-\rho^2)$',
           'FE':0.0,
           'FEVar':r'$\lambda^2\sigma^2/(1-(1-\lambda)^2\rho^2)$',
           'FEATV':r'$(1-\lambda)\rho\text{FEVar}$',
           'Disg':0.0,
           'DisgVar':0.0,
           'DisgATV':0.0,
           'Var':r'$\sigma^2$',
            'VarVar':0.0,
            'VarATV':0.0
           }

sear_mom = pd.DataFrame([sear_mom_dct])
sear_mom.index = ['SE+AR']

# %%
## data_moments 


data_mom_SPF = pd.DataFrame([dict(data_moms_dct_SPF)])
data_mom_SPF.index = ['SPF']
data_mom_SCE = pd.DataFrame([dict(data_moms_dct_SCE)])
data_mom_SCE.index = ['SCE']

data_mom_df = pd.concat([data_mom_SPF,
                         data_mom_SCE,
                         fire_ar_mom,
                        fire_sv_mom])

data_mom_df = data_mom_df.applymap(lambda x: round(x, 3) 
                                   if isinstance(x, (int, float)) else x)


### keep only selected moments 

data_mom_df = data_mom_df.drop(columns=['FEATV',
                                        'DisgVar',
                                        'DisgATV',
                                        'VarVar',
                                        'VarATV'])

data_mom_df.T.to_excel('tables/data_moments.xlsx')
data_mom_df.T
# Out:
#          SPF  SCE                           FIRE+AR  \
# InfAV   0.00 0.00                              0.00
# InfVar  0.17 0.65      $\sigma^2_\omega/(1-\rho^2)$
# InfATV -0.04 0.61  $\rho\sigma^2_\omega/(1-\rho^2)$
# FE      0.12 1.81                              0.00
# FEVar   0.14 0.94                 $\sigma^2_\omega$
# Disg    0.16 2.81                              0.00
# Var     0.21 1.75                 $\sigma^2_\omega$
#
#                                        FIRE+SV
# InfAV                                     0.00
# InfVar                                     N/A
# InfATV                                     N/A
# FE                                        0.00
# FEVar   $\bar\sigma^2_{\eta}+\bar\sigma^2_{z}$
# Disg                                      0.00
# Var     $\bar\sigma^2_{\eta}+\bar\sigma^2_{z}$

# %% [markdown]
# ### Data moments

# %%
## real time and history 

################
## quarterly ###
#################

real_time_Q_ar = np.array(SPF_est['RTCPICore'])
history_Q_ar = np.array(historyQ['RTCPICore'])
process_paraQ_est_ar = np.array([rhoQ_est,sigmaQ_est])

##############
## monthly ###
#############

real_time_M_ar = np.array(SCE_est['RTCPI'])
history_M_ar = np.array(historyM['RTCPI'])

process_paraM_est_ar = np.array([rhoM_est,
                                 sigmaM_est])

# %% [markdown]
# #### SV  parameters and data

# %%
################
## quarterly ##
################

### quarterly data 
### exporting inflation series for process estimation using UCSV model in matlab

CPICQ.to_excel("../OtherData/CPICQ.xlsx")  ## this is for matlab estimation of UCSV model

################
## monthly ####
################

### process parameters estimation 

### exporting monthly inflation series for process estimation using UCSV model in matlab
CPIM.to_excel("../OtherData/CPIM.xlsx")  ## this is for matlab estimation of UCSV model

##########################################################################
##########################################################################
##########################################################################
## use matlab code stockwatson.m to estimate UCSV model before moving on!
##########################################################################
##########################################################################
##########################################################################
##########################################################################


## process parameters estimation for SV 

################
## quarterly ##
################

### import the estimated results 
CPICQ_UCSV_Est = pd.read_excel('../OtherData/UCSVestQ.xlsx')  
CPICQ_UCSV_Est.index = pd.to_datetime(CPICQ_UCSV_Est['date'],format='%Y%m%d')
CPICQ_UCSV_Est = CPICQ_UCSV_Est.drop(columns=['date'])
CPICQ_UCSV_Est = CPICQ_UCSV_Est.rename(columns = {'sd_eps':'sd_p_est',
                                      'sd_eta':'sd_t_est',
                                      'tau':'p'})  ## Loading ucsv model estimates 



################
## monthly ####
################

### import the estimated results 
CPIM_UCSV_Est = pd.read_excel('../OtherData/UCSVestM.xlsx')  
CPIM_UCSV_Est.index =pd.to_datetime(CPIM_UCSV_Est['date'],format='%Y%m%d')
CPIM_UCSV_Est = CPIM_UCSV_Est.drop(columns=['date'])
CPIM_UCSV_Est = CPIM_UCSV_Est.rename(columns = {'sd_eps':'sd_p_est',
                                                'sd_eta':'sd_t_est',
                                                'tau':'p'})  ## Loading ucsv model estimates 

########################################################################################
## be careful with the order, I define eta as the permanent and eps to be the transitory
 ######################################################################################
    

### quarterly plot 

plt.figure(figsize=(10,5))
plt.plot(CPICQ_UCSV_Est['sd_p_est'],
         'r--',
          lw = lw,
         label='permanent volatility')
plt.plot(CPICQ_UCSV_Est['sd_t_est'],
         'k-.',
         lw = lw,
         label='transitory volatility')
plt.title('Estimated Stochastic Volatility of Core CPI Inflation')
plt.ylabel('std')
plt.legend(loc=1)
plt.savefig('../graphs/inflation/UCSVQ.png')
    
### monthly plot 

plt.figure(figsize=(10,5))
plt.plot(CPIM_UCSV_Est['sd_p_est'],
         'r--',
          lw = lw,
         label='permanent volatility')
plt.plot(CPIM_UCSV_Est['sd_t_est'],
         'k-.',
         lw = lw,
         label='transitory volatility')
plt.title('Estimated Stochastic Volatility of CPI Inflation')
plt.ylabel('std')
plt.legend(loc=1)
plt.savefig('../graphs/inflation/UCSVM.png')

# %%
#########################################################
## specific to SV model  
######################################################

#############
## quarterly 
##############

n_burn_rt_historyQ = len(CPICQ_UCSV_Est) - len(historyQ)  

history_yQ = np.array(historyQ['RTCPICore'])
history_vol_pQ = np.array(CPICQ_UCSV_Est['sd_p_est'][n_burn_rt_historyQ:])**2  ## permanent
history_vol_tQ = np.array(CPICQ_UCSV_Est['sd_t_est'][n_burn_rt_historyQ:])**2 ## transitory

#history_volsQ = np.array([history_vol_pQ,
#                          history_vol_tQ])
history_pQ = np.array(CPICQ_UCSV_Est['p'][n_burn_rt_historyQ:])

## to burn 
n_burn_Q = len(history_pQ) - len(SPF_est['RTCPI'])
real_time_yQ = history_yQ[n_burn_Q:]
real_time_vol_pQ = history_vol_pQ[n_burn_Q:]
real_time_vol_tQ = history_vol_tQ[n_burn_Q:]
real_time_pQ = history_pQ[n_burn_Q:]

############
## monthly
############

n_burn_rt_historyM = len(CPIM_UCSV_Est) - len(historyM)  

history_yM = np.array(historyM['RTCPI'])
history_vol_pM = np.array(CPIM_UCSV_Est['sd_p_est'][n_burn_rt_historyM:])**2
history_vol_tM = np.array(CPIM_UCSV_Est['sd_t_est'][n_burn_rt_historyM:])**2

#history_volsM = np.array([history_vol_pM,
#                          history_vol_tM])  ## order is import 

history_pM = np.array(CPIM_UCSV_Est['p'][n_burn_rt_historyM:])

## to burn 
n_burn_M = len(history_pM) - len(SCE_est['RTCPI'])
real_time_yM = history_yM[n_burn_M:]
real_time_vol_pM = history_vol_pM[n_burn_M:]
real_time_vol_tM = history_vol_tM[n_burn_M:]
real_time_pM = history_pM[n_burn_M:]

# %%
## generate histories and real time array 

history_Q_sv = np.array([history_yQ,
                           history_pQ,
                           history_vol_pQ,
                           history_vol_tQ])
history_M_sv = np.array([history_yM,
                           history_pM,
                           history_vol_pM,
                           history_vol_tM])

real_time_Q_sv = np.array([real_time_yQ,
                         real_time_pQ,
                         real_time_vol_pQ,
                         real_time_vol_tQ])
real_time_M_sv = np.array([real_time_yM,
                         real_time_pM,
                         real_time_vol_pM,
                         real_time_vol_tM])

# %%
## process parameters 
process_paraQ_est_sv = np.array([0.2])
process_paraM_est_sv = np.array([0.2])

# %% [markdown]
# ### Estimation

# %%
agents_list = ['SPF',
               'SCE']

horizon_list = [4,
               12]

process_list = ['AR',
                'SV'
               ]

ex_model_list = ['SE',
                 'NI',
                 'DE',
                 'DENI'
                ]
nb_ex_model = len(ex_model_list)

moments_list = [['FE','FEVar','FEATV'],
               ['FE','FEVar','FEATV','Disg'],
               ['FE','FEVar','FEATV','Disg','Var']]

nb_moments = len(moments_list)

how_list =['2-step','Joint']

moments_list_general = ['FE','FE+Disg','FE+Disg+Var']

model_list = [sear0,
              niar0,
              dear0,
              deniar0,
              sesv0,
              nisv0,
              desv0,
              denisv0
]

algorithm_list = ['trust-constr',
                 'trust-constr',
                 'trust-constr',
                 'trust-constr',
                 'trust-constr',
                 'trust-constr',
                 'trust-constr',
                 'trust-constr'
                 ]


algorithm_joint_list = ['trust-constr',
                        'trust-constr',
                        'trust-constr',
                        'trust-constr',
                        None,
                        None,
                        None,
                        None
]

bns_list =[((0,1),),
           ((0,3),(0,3),),
           ((-2,2),(0,5),),
           ((-3,3),(0,3),),
           ((0,1),),
           ((0,3),(0,3),),
           ((-2,2),(0,np.inf),),
           ((-3,3),(0,3),)
]

bns_joint_list =[((0,1),(0.9,1),(0,np.inf),),
                 ((0,3),(0,3),(0.9,1),(0,np.inf),),
                 ((-2,2),(0,5),(0.9,1),(0,np.inf),),
                 ((-3,3),(0,3),(0.9,1),(0,np.inf),),
                 None,
                 None,
                 None,
                 None
]

data_mom_dict_list = [data_moms_dct_SPF,
                      data_moms_dct_SCE]

process_paras_list = [process_paraQ_est_ar,
                      process_paraQ_est_sv,
                      process_paraM_est_ar,
                      process_paraM_est_sv
]

realized_list = [realized_CPIC.astype(np.float64),
                 realized_CPI.astype(np.float64)]

real_time_list = [np.array(real_time_Q_ar),
                 np.array(real_time_Q_sv),  ## 4 x t array 
                np.array(real_time_M_ar),
                np.array(real_time_M_sv)
]  ## 4 x t array 

history_list = [np.array(history_Q_ar),
               np.array(history_Q_sv),     ## 4 x t array 
               np.array(history_M_ar), 
               np.array(history_M_sv)
]     ## 4 x t array 

## parameter guesses 
guesses_list = [np.array([0.2]),  ## se lbd 
               np.array([0.5,0.8]),  ## ni sigma_pb, sigma_pr
               np.array([0.3,0.4]),   ## de theta theta_sigma
               np.array([0.1,0.3])
               ]  ## deni theta, sigma_pb, sigma_pr

guesses_joint_list = [np.array([0.2,0.98,0.1]),            ## se lbd 
                     np.array([0.1,0.2,0.95,0.1]),      ## ni sigma_pb, sigma_pr
                     np.array([0.3,0.4,0.95,0.1]),      ## de theta theta_sigma
                     np.array([0.1,0.3,0.95,0.1]),  ## theta, sigma_pb, sigma_pr  
                       ## for sv models not used
                      np.array([0.3,0.2]),            ## se lbd 
                      np.array([0.1,0.2,0.2]),      ## ni sigma_pb, sigma_pr
                       np.array([0.3,0.2]),      ## de theta theta_sigma
                       np.array([0.1,0.2])
                     ]  ## deni theta, sigma_pb, sigma_pr]

n_exp_paras_list = [1,
                    2,
                    2,
                    2]


## names labels 

se_ar_names = [r'$\hat\lambda$',
                   r'$\rho$',
                   r'$\sigma$',
                   r'$\hat\lambda$', 
                   r'$\rho$',
                   r'$\sigma$']


ni_ar_names = [r'$\hat\sigma_{pb}$',
                   r'$\hat\sigma_{pr}$',
                   r'$\rho$',
                   r'$\sigma$',
                   r'$\hat\sigma_{pb}$',
                   r'$\hat\sigma_{pr}$',
                   r'NI: $\rho$',
                   r'NI: $\sigma$']


de_ar_names = [r'$\hat\theta$',
                   r'$\sigma_\theta$',
                   r'$\rho$',
                   r'$\sigma$',
                   r'$\hat\theta$',
                   r'$\sigma_\theta$',
                   r'$\rho$',
                   r'$\sigma$']


deni_ar_names = [r'$\hat\theta$',
                  # r'$\hat\sigma_{pb}$',
                   r'$\hat\sigma_{pr}$',
                   r'$\rho$',
                   r'$\sigma$',
                   r'$\hat\theta$',
                  # r'$\hat\sigma_{pb}$',
                   r'$\hat\sigma_{pr}$',
                   r'$\rho$',
                   r'$\sigma$']

se_sv_names = [r'$\hat\lambda$',
               r'$\gamma$']


ni_sv_names = [r'$\hat\sigma_{pb}$',
               r'$\hat\sigma_{pr}$',
               r'$\gamma$']


de_sv_names = [r'$\hat\theta$',
               r'$\sigma_\theta$',                   
               r'$\gamma$']


deni_sv_names = [r'$\hat\theta$',
                  # r'$\hat\sigma_{pb}$',
                   r'$\hat\sigma_{pr}$',
                   r'$\gamma$']


names_list = [se_ar_names,
             ni_ar_names,
             de_ar_names,
             deni_ar_names,
             se_sv_names,
             ni_sv_names,
             de_sv_names,
             deni_sv_names]

# %%
################################################################################
## A loop to estimate the model for different agents, theory, inflation process and joint/2-step 
#################################################################################

paras_list = []
paras_step2_list = []
paras_joint_list = []
paras_joint_step2_list = []

for agent_id,agent in enumerate(agents_list):
    print(agent)
    realized_this = realized_list[agent_id]
    data_mom_dict_this = data_mom_dict_list[agent_id]
    for pg_id,process in enumerate(process_list):
        print(process)
        ## history and real-time inflation that is fed in the model depends on agent type and process
        agent_process_id = agent_id*2+pg_id       
        process_paras_this = process_paras_list[agent_process_id]
        real_time_this = real_time_list[agent_process_id]
        history_this = history_list[agent_process_id] 
        
        for exp_id,ex_model in enumerate(ex_model_list):
            print(ex_model)
            model_idx  = pg_id*nb_ex_model+exp_id
            print(model_idx)
            model_instance = model_list[model_idx]
            alg_this= algorithm_list[model_idx]
            bounds_this = bns_list[model_idx]
            print('2-step estimation uses algorithm'+alg_this)
            print('bounds for parameters'+str(bounds_this))
            alg_joint_this= algorithm_joint_list[model_idx]
            bounds_joint_this = bns_joint_list[model_idx]
            names_this = names_list[model_idx]

            ## feed inputs to the instance 
            instance = model_instance

            print(instance)
            print('horizon', horizon_list[agent_id])
            instance.horizon = horizon_list[agent_id]
            
            instance.GetRealization(realized_this)
            instance.real_time = real_time_this
            instance.history = history_this
            instance.process_para = process_paras_this 
            
            ## model-specific estimates holder 
            
            paras_list_this_model = []
            paras_step2_list_this_model = []
            paras_joint_list_this_model = []
            paras_joint_step2_list_this_model = []
            
            ## specific objetive function to minimize (only for expectation)

            for mom_id, moments_this in enumerate(moments_list):
                print(moments_this)
                print('Step 1')
                def Obj_this(paras_this):  
                    scalor = ObjGen(instance,
                                    paras = paras_this,
                                    data_mom_dict = data_mom_dict_this,
                                    moment_choice = List(moments_this),
                                    how ='expectation')
                    return scalor
                
                guess_this = guesses_list[exp_id]
                ## estimating
                para_est  = ParaEst(Obj_this,
                                 para_guess = guess_this,
                                 method= alg_this,
                                bounds = bounds_this)
                
                ## try it another time if no convergence 
                if np.isnan(para_est).any()==True:
                    para_est  = ParaEst(Obj_this,
                                 para_guess = guess_this,
                                 method= alg_this,
                                bounds = bounds_this)
                    
                ## same para est
                if np.isnan(para_est).any()==False:
                    
                    ## compute the efficient weighting matrix 
                    instance.exp_para = para_est
                    smm_dict_this = instance.SMM()
                    distance = np.array([smm_dict_this[mom] - data_mom_dict_this[mom] for mom in moments_this]) 
                    distance_diag = np.diag(distance*distance.T)
                    wm1st = np.linalg.inv(distance_diag)

                    ## 2-step estimation using efficient matrix 
                    def Obj_this_step2(paras_this):
                        scalor = ObjWeight(instance,
                                           paras = paras_this,
                                           weight = wm1st,
                                           data_mom_dict = data_mom_dict_this,
                                           moment_choice = List(moments_this),
                                           how ='expectation')
                        return scalor
                    para_est_step2  = ParaEst(Obj_this_step2,
                                        para_guess = guess_this,
                                        method= alg_this,
                                        bounds = bounds_this)
                    if np.isnan(para_est_step2).any()==True:
                        print('the 2-step estimation is nan')
                        para_est_step2_nan = np.array([np.nan])
                        para_est_step2 = para_est_step2_nan
                else:
                    print('the estimation is nan')
                    para_est_nan = np.array([np.nan])
                    para_est = para_est_nan
                                        
                    para_est_step2_nan = np.array([np.nan])
                    para_est_step2 = para_est_step2_nan
                    
                ## save para est
                
                para_est = np.round(para_est,2)
                print('Step 1:'+str(para_est))
                paras_list_this_model.append(para_est)
                paras_list.append(para_est)
                
                para_est_step2 = np.round(para_est_step2,2)
                print('Step 2:'+str(para_est_step2))
                paras_step2_list_this_model.append(para_est_step2)
                paras_step2_list.append(para_est_step2)
                
                
                ##  joint estimation 
                n_exp_paras_this = n_exp_paras_list[exp_id]
                
                moments_this_ = List(moments_this+['InfAV','InfVar','InfATV']) ## added inflation moments 
                
                if pg_id <=0: ## no joint estimation for SV models 
                    def Obj_joint_this(paras):
                        scalor = ObjGen(instance,
                                        paras = paras,
                                        data_mom_dict = data_mom_dict_this,
                                        moment_choice = moments_this_,
                                        how = 'joint',
                                        n_exp_paras = n_exp_paras_this)
                        return scalor

                    guess_this_ = guesses_joint_list[model_idx]
                    ## estimating
                    paras_joint_est = ParaEst(Obj_joint_this,
                                              para_guess = guess_this_,
                                              method= alg_joint_this,
                                              bounds = bounds_joint_this) ##Nelder-Mead  
                    if  np.isnan(paras_joint_est).any()==False:
                        ## compute the efficient weighting matrix 
                        instance.exp_para = paras_joint_est[0:n_exp_paras_this]     
                        instance.process_para = paras_joint_est[n_exp_paras_this:]
                        smm_dict_this = instance.SMM()
                        distance = np.array([smm_dict_this[mom] - data_mom_dict_this[mom] for mom in moments_this_]) 
                        distance_diag = np.diag(distance*distance.T)
                        wm1st = np.linalg.inv(distance_diag)

                        ## 2-step estimation using efficient matrix 
                        def Obj_joint_this_step2(paras_this):
                            scalor = ObjWeight(instance,
                                               paras = paras_this,
                                               weight = wm1st,
                                               data_mom_dict = data_mom_dict_this,
                                               moment_choice = moments_this_,
                                               how ='joint',
                                               n_exp_paras = n_exp_paras_this)
                            return scalor
                        ## re-estimating
                        para_est_joint_step2  = ParaEst(Obj_joint_this_step2,
                                                        para_guess = guess_this_,
                                                        method = alg_joint_this,
                                                        bounds = bounds_joint_this)     #  Nelder-Mead
                        if np.isnan(para_est_joint_step2).any()==True:
                            print('the 2-step estimation is nan')
                            para_est_joint_step2 = np.array([np.nan])
                        
                    else:
                        print('the estimation is nan')
                        paras_joint_est = np.array([np.nan])
                        para_est_joint_step2 = np.array([np.nan])
                
                else:
                    paras_joint_est = np.array([np.nan])
                    para_est_joint_step2 = np.array([np.nan])
                
                ## save in the list 
                paras_joint_est = np.round(paras_joint_est,2)
                print('Step 1:'+str(paras_joint_est))
                paras_joint_list_this_model.append(paras_joint_est)
                paras_joint_list.append(paras_joint_est)
                
                para_est_joint_step2 = np.round(para_est_joint_step2,2)
                print('Step 2:'+str(para_est_joint_step2))
                paras_joint_step2_list_this_model.append(para_est_joint_step2)
                paras_joint_step2_list.append(para_est_joint_step2)
            
            
            ### export model-specific estimates 
            names = names_list[model_idx]
            #print(paras_step2_list_this_model)
            #print(paras_joint_step2_list_this_model)
            para_est_tab_this_model = pd.DataFrame(paras_step2_list_this_model,
                                            index = moments_list_general)
            para_est_process_tab_this_model = pd.DataFrame([process_paras_this]*nb_moments,
                                            index = moments_list_general)
            para_joint_est_tab_this_model = pd.DataFrame(paras_joint_step2_list_this_model,
                                            index = moments_list_general)
            para_all_est_tab_this_model = pd.concat([para_est_tab_this_model,
                                                     para_est_process_tab_this_model,
                                                     para_joint_est_tab_this_model],
                                                    join = 'inner', axis=1)
            print(names_this)
            try:
                para_all_est_tab_this_model.columns = names_this 
            except:
                pass
            para_all_est_tab_this_model.to_excel('tables/after2022/'+agent+'_'+process+'_'+ex_model+'.xlsx',
                                       float_format='%.2f',
                                       index = True)
# Out:
# SPF
# AR
# SE
# 0
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((0, 1),)
# <numba.experimental.jitclass.boxing.StickyExpectationAR object at 0x0000020C411E4A30>
# horizon 4
# ['FE', 'FEVar', 'FEATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.19 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 69, function evaluations: 122, CG iterations: 59, optimality: 7.21e-09, constraint violation: 0.00e+00, execution time:  2.2 s.
# Step 1:[0.36]
# Step 2:[0.27]
# `gtol` termination condition is satisfied.
# Number of iterations: 36, function evaluations: 116, CG iterations: 43, optimality: 7.76e-09, constraint violation: 0.00e+00, execution time:  2.0 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 42, function evaluations: 136, CG iterations: 91, optimality: 6.88e-09, constraint violation: 0.00e+00, execution time:  1.9 s.
# Step 1:[0.51 0.99 0.04]
# Step 2:[0.19 1.   0.02]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.13 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 62, function evaluations: 110, CG iterations: 52, optimality: 7.26e-09, constraint violation: 0.00e+00, execution time:  1.5 s.
# Step 1:[0.36]
# Step 2:[0.26]
# `gtol` termination condition is satisfied.
# Number of iterations: 128, function evaluations: 604, CG iterations: 157, optimality: 7.26e-09, constraint violation: 0.00e+00, execution time:  6.5 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 130, function evaluations: 36, CG iterations: 352, optimality: 4.79e+01, constraint violation: 0.00e+00, execution time: 0.79 s.
# Step 1:[0.24 0.99 0.03]
# Step 2:[0.2  0.98 0.1 ]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.11 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.12 s.
# Step 1:[0.36]
# Step 2:[0.36]
# `gtol` termination condition is satisfied.
# Number of iterations: 36, function evaluations: 120, CG iterations: 42, optimality: 6.97e-09, constraint violation: 0.00e+00, execution time:  1.7 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 130, function evaluations: 32, CG iterations: 352, optimality: 6.32e+00, constraint violation: 0.00e+00, execution time:  1.4 s.
# Step 1:[0.5  0.99 0.04]
# Step 2:[0.2  0.98 0.1 ]
# ['$\\hat\\lambda$', '$\\rho$', '$\\sigma$', '$\\hat\\lambda$', '$\\rho$', '$\\sigma$']
# NI
# 1
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((0, 3), (0, 3))
# <numba.experimental.jitclass.boxing.NoisyInformationAR object at 0x0000020C47C99C10>
# horizon 4
# ['FE', 'FEVar', 'FEATV']
# Step 1
# C:\Users\want\OneDrive - Bank of Canada\MyDocs\GitHub\InfVar\workingfolder\python\SMMEst.py:222: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (Array(float64, 1, 'C', False, aligned=True), Array(float64, 1, 'A', False, aligned=True))
#   model_mom_dict = model.SMM()
# `gtol` termination condition is satisfied.
# Number of iterations: 27, function evaluations: 60, CG iterations: 30, optimality: 2.47e-09, constraint violation: 0.00e+00, execution time:  6.0 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 31, function evaluations: 69, CG iterations: 39, optimality: 2.12e-09, constraint violation: 0.00e+00, execution time:  5.7 s.
# Step 1:[2.99 0.04]
# Step 2:[2.98 0.  ]
# `gtol` termination condition is satisfied.
# Number of iterations: 41, function evaluations: 155, CG iterations: 92, optimality: 1.96e-09, constraint violation: 0.00e+00, execution time: 1.8e+01 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 136, function evaluations: 845, CG iterations: 351, optimality: 3.31e-07, constraint violation: 0.00e+00, execution time: 1e+02 s.
# Step 1:[0.   0.23 0.99 0.04]
# Step 2:[0.   0.16 0.99 0.04]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 23, function evaluations: 39, CG iterations: 21, optimality: 2.88e-09, constraint violation: 0.00e+00, execution time:  5.0 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 177, function evaluations: 492, CG iterations: 293, optimality: 3.20e-01, constraint violation: 0.00e+00, execution time: 6.7e+01 s.
# Step 1:[0.   0.82]
# Step 2:[0.03 0.8 ]
# `gtol` termination condition is satisfied.
# Number of iterations: 43, function evaluations: 170, CG iterations: 101, optimality: 8.48e-09, constraint violation: 0.00e+00, execution time: 2.4e+01 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 152, function evaluations: 900, CG iterations: 340, optimality: 8.72e-06, constraint violation: 0.00e+00, execution time: 1.3e+02 s.
# Step 1:[0.   0.18 0.99 0.04]
# Step 2:[0.   0.19 0.99 0.04]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 23, function evaluations: 39, CG iterations: 21, optimality: 2.82e-09, constraint violation: 0.00e+00, execution time:  6.2 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 160, function evaluations: 525, CG iterations: 253, optimality: 4.41e-01, constraint violation: 0.00e+00, execution time: 7.6e+01 s.
# Step 1:[0.   0.84]
# Step 2:[0.03 0.85]
# `gtol` termination condition is satisfied.
# Number of iterations: 41, function evaluations: 160, CG iterations: 100, optimality: 8.95e-09, constraint violation: 0.00e+00, execution time: 2.1e+01 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 50, function evaluations: 210, CG iterations: 135, optimality: 8.72e-09, constraint violation: 0.00e+00, execution time: 2.7e+01 s.
# Step 1:[0.   0.2  0.98 0.05]
# Step 2:[0.   0.19 0.99 0.05]
# ['$\\hat\\sigma_{pb}$', '$\\hat\\sigma_{pr}$', '$\\rho$', '$\\sigma$', '$\\hat\\sigma_{pb}$', '$\\hat\\sigma_{pr}$', 'NI: $\\rho$', 'NI: $\\sigma$']
# DE
# 2
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((-2, 2), (0, 5))
# <numba.experimental.jitclass.boxing.DiagnosticExpectationAR object at 0x0000020C4A060520>
# horizon 4
# ['FE', 'FEVar', 'FEATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 51, function evaluations: 195, CG iterations: 57, optimality: 1.18e-08, constraint violation: 0.00e+00, execution time: 0.39 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 80, function evaluations: 246, CG iterations: 112, optimality: 6.78e-07, constraint violation: 0.00e+00, execution time: 0.45 s.
# Step 1:[0.12 1.9 ]
# Step 2:[0.47 0.52]
# `gtol` termination condition is satisfied.
# Number of iterations: 45, function evaluations: 175, CG iterations: 99, optimality: 5.28e-09, constraint violation: 0.00e+00, execution time: 0.36 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 95, function evaluations: 580, CG iterations: 259, optimality: 2.78e-06, constraint violation: 0.00e+00, execution time: 0.87 s.
# Step 1:[0.52 0.75 0.98 0.05]
# Step 2:[0.71 0.4  0.98 0.05]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 20, function evaluations: 42, CG iterations: 16, optimality: 9.95e-09, constraint violation: 0.00e+00, execution time: 0.19 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 71, function evaluations: 189, CG iterations: 112, optimality: 6.97e-07, constraint violation: 0.00e+00, execution time: 0.54 s.
# Step 1:[0.55 2.13]
# Step 2:[0.73 2.17]
# `gtol` termination condition is satisfied.
# Number of iterations: 56, function evaluations: 260, CG iterations: 127, optimality: 5.09e-09, constraint violation: 0.00e+00, execution time: 0.59 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 114, function evaluations: 655, CG iterations: 316, optimality: 2.45e-05, constraint violation: 0.00e+00, execution time:  1.1 s.
# Step 1:[0.53 2.13 0.98 0.05]
# Step 2:[0.69 2.17 0.98 0.05]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 24, function evaluations: 45, CG iterations: 17, optimality: 5.50e-09, constraint violation: 0.00e+00, execution time: 0.22 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 237, CG iterations: 104, optimality: 1.23e-06, constraint violation: 0.00e+00, execution time: 0.51 s.
# Step 1:[0.54 2.13]
# Step 2:[0.69 2.17]
# `gtol` termination condition is satisfied.
# Number of iterations: 45, function evaluations: 180, CG iterations: 88, optimality: 6.69e-09, constraint violation: 0.00e+00, execution time:  0.5 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 7555, CG iterations: 3193, optimality: 2.49e+01, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# the 2-step estimation is nan
# Step 1:[0.72 2.15 0.98 0.06]
# Step 2:[nan]
# ['$\\hat\\theta$', '$\\sigma_\\theta$', '$\\rho$', '$\\sigma$', '$\\hat\\theta$', '$\\sigma_\\theta$', '$\\rho$', '$\\sigma$']
# DENI
# 3
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((-3, 3), (0, 3))
# <numba.experimental.jitclass.boxing.DENIHybridAR object at 0x0000020C4A1AD9A0>
# horizon 4
# ['FE', 'FEVar', 'FEATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 37, function evaluations: 66, CG iterations: 39, optimality: 8.08e-09, constraint violation: 0.00e+00, execution time:  0.6 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 131, function evaluations: 81, CG iterations: 229, optimality: 8.45e+00, constraint violation: 0.00e+00, execution time: 0.76 s.
# Step 1:[0.82 0.  ]
# Step 2:[0.65 0.49]
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 125, function evaluations: 610, CG iterations: 239, optimality: 1.68e-09, constraint violation: 0.00e+00, execution time:  3.4 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 107, function evaluations: 575, CG iterations: 271, optimality: 5.13e-07, constraint violation: 0.00e+00, execution time:  2.2 s.
# Step 1:[0.79 0.   0.98 0.05]
# Step 2:[0.8  0.   0.99 0.05]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 112, function evaluations: 39, CG iterations: 109, optimality: 8.70e-03, constraint violation: 0.00e+00, execution time: 0.27 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 83, function evaluations: 225, CG iterations: 129, optimality: 9.51e-06, constraint violation: 0.00e+00, execution time: 0.92 s.
# Step 1:[0.21 0.35]
# Step 2:[0.21 0.35]
# `gtol` termination condition is satisfied.
# Number of iterations: 55, function evaluations: 245, CG iterations: 129, optimality: 2.32e-09, constraint violation: 0.00e+00, execution time:  1.0 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 30, CG iterations: 5993, optimality: 9.23e+05, constraint violation: 0.00e+00, execution time:  2.9 s.
# the 2-step estimation is nan
# Step 1:[0.8  0.15 0.98 0.05]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 141, CG iterations: 97, optimality: 1.75e-08, constraint violation: 0.00e+00, execution time: 0.64 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 196, function evaluations: 693, CG iterations: 317, optimality: 1.33e-04, constraint violation: 0.00e+00, execution time:  2.9 s.
# Step 1:[0.83 0.17]
# Step 2:[0.87 0.15]
# `gtol` termination condition is satisfied.
# Number of iterations: 49, function evaluations: 205, CG iterations: 101, optimality: 4.73e-09, constraint violation: 0.00e+00, execution time: 0.85 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 30, CG iterations: 5993, optimality: 2.28e+07, constraint violation: 0.00e+00, execution time:  4.3 s.
# the 2-step estimation is nan
# Step 1:[0.8  0.15 0.98 0.06]
# Step 2:[nan]
# ['$\\hat\\theta$', '$\\hat\\sigma_{pr}$', '$\\rho$', '$\\sigma$', '$\\hat\\theta$', '$\\hat\\sigma_{pr}$', '$\\rho$', '$\\sigma$']
# SV
# SE
# 4
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((0, 1),)
# <numba.experimental.jitclass.boxing.StickyExpectationSV object at 0x0000020C47C993A0>
# horizon 4
# ['FE', 'FEVar', 'FEATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 118, CG iterations: 57, optimality: 7.23e-09, constraint violation: 0.00e+00, execution time:  1.6 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 82, function evaluations: 148, CG iterations: 72, optimality: 7.27e-09, constraint violation: 0.00e+00, execution time:  3.0 s.
# Step 1:[0.26]
# Step 2:[0.25]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 42, function evaluations: 64, CG iterations: 32, optimality: 7.20e-09, constraint violation: 0.00e+00, execution time:  1.6 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 50, function evaluations: 80, CG iterations: 40, optimality: 7.05e-09, constraint violation: 0.00e+00, execution time:  1.8 s.
# Step 1:[0.27]
# Step 2:[0.29]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 53, function evaluations: 86, CG iterations: 43, optimality: 7.17e-09, constraint violation: 0.00e+00, execution time:  2.1 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 82, function evaluations: 152, CG iterations: 72, optimality: 7.08e-09, constraint violation: 0.00e+00, execution time:  3.4 s.
# Step 1:[0.27]
# Step 2:[0.28]
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\lambda$', '$\\gamma$']
# NI
# 5
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((0, 3), (0, 3))
# <numba.experimental.jitclass.boxing.NoisyInformationSV object at 0x0000020C49F48F70>
# horizon 4
# ['FE', 'FEVar', 'FEATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 25, function evaluations: 45, CG iterations: 22, optimality: 2.80e-09, constraint violation: 0.00e+00, execution time:  8.0 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 24, function evaluations: 42, CG iterations: 23, optimality: 2.16e-09, constraint violation: 0.00e+00, execution time:  7.6 s.
# Step 1:[2.15 3.  ]
# Step 2:[1.03 3.  ]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 24, function evaluations: 42, CG iterations: 20, optimality: 2.76e-09, constraint violation: 0.00e+00, execution time:  8.0 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 24, function evaluations: 42, CG iterations: 23, optimality: 2.16e-09, constraint violation: 0.00e+00, execution time:  6.4 s.
# Step 1:[2.14 3.  ]
# Step 2:[1.03 3.  ]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 24, function evaluations: 42, CG iterations: 20, optimality: 2.76e-09, constraint violation: 0.00e+00, execution time:  5.8 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 25, function evaluations: 45, CG iterations: 27, optimality: 2.35e-09, constraint violation: 0.00e+00, execution time:  7.1 s.
# Step 1:[2.14 3.  ]
# Step 2:[2.02 3.  ]
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\sigma_{pb}$', '$\\hat\\sigma_{pr}$', '$\\gamma$']
# DE
# 6
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((-2, 2), (0, inf))
# <numba.experimental.jitclass.boxing.DiagnosticExpectationSV object at 0x0000020C47C6FDC0>
# horizon 4
# ['FE', 'FEVar', 'FEATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 57, function evaluations: 84, CG iterations: 64, optimality: 4.03e-08, constraint violation: 0.00e+00, execution time: 0.92 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 65, function evaluations: 228, CG iterations: 80, optimality: 1.37e-05, constraint violation: 0.00e+00, execution time:  2.0 s.
# Step 1:[0.05 0.48]
# Step 2:[0.06 0.5 ]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 25, function evaluations: 54, CG iterations: 22, optimality: 3.44e-09, constraint violation: 0.00e+00, execution time: 0.58 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 99, function evaluations: 360, CG iterations: 119, optimality: 1.02e-04, constraint violation: 0.00e+00, execution time:  3.3 s.
# Step 1:[0.05 0.16]
# Step 2:[0.06 0.16]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 59, function evaluations: 132, CG iterations: 86, optimality: 1.31e-08, constraint violation: 0.00e+00, execution time:  1.3 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 109, function evaluations: 438, CG iterations: 137, optimality: 1.42e-04, constraint violation: 0.00e+00, execution time:  4.1 s.
# Step 1:[0.05 0.16]
# Step 2:[0.06 0.16]
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\theta$', '$\\sigma_\\theta$', '$\\gamma$']
# DENI
# 7
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((-3, 3), (0, 3))
# <numba.experimental.jitclass.boxing.DENIHybridSV object at 0x0000020C49A9D040>
# horizon 4
# ['FE', 'FEVar', 'FEATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 136, function evaluations: 132, CG iterations: 127, optimality: 2.52e-02, constraint violation: 0.00e+00, execution time: 5.5e+01 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 122, function evaluations: 12, CG iterations: 112, optimality: 6.02e+00, constraint violation: 0.00e+00, execution time:  4.5 s.
# Step 1:[0.85 1.86]
# Step 2:[0.58 0.83]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 168, function evaluations: 231, CG iterations: 242, optimality: 1.55e-02, constraint violation: 0.00e+00, execution time: 8e+01 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 127, function evaluations: 39, CG iterations: 129, optimality: 4.36e+00, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# Step 1:[0.82 1.92]
# Step 2:[0.76 0.83]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 168, function evaluations: 228, CG iterations: 160, optimality: 1.56e-02, constraint violation: 0.00e+00, execution time: 9e+01 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 122, function evaluations: 12, CG iterations: 112, optimality: 5.42e+00, constraint violation: 0.00e+00, execution time:  3.8 s.
# Step 1:[0.81 1.91]
# Step 2:[0.6 0.8]
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\theta$', '$\\hat\\sigma_{pr}$', '$\\gamma$']
# SCE
# AR
# SE
# 0
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((0, 1),)
# <numba.experimental.jitclass.boxing.StickyExpectationAR object at 0x0000020C411E4A30>
# horizon 12
# ['FE', 'FEVar', 'FEATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.35 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.35 s.
# Step 1:[0.36]
# Step 2:[0.36]
# `xtol` termination condition is satisfied.
# Number of iterations: 1083, function evaluations: 4644, CG iterations: 2347, optimality: 3.02e-07, constraint violation: 0.00e+00, execution time: 3.3e+02 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 284, function evaluations: 1696, CG iterations: 447, optimality: 3.63e+05, constraint violation: 0.00e+00, execution time: 1.2e+02 s.
# Step 1:[0.25 1.   0.  ]
# Step 2:[0.18 1.   0.03]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.25 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.25 s.
# Step 1:[0.36]
# Step 2:[0.36]
# `xtol` termination condition is satisfied.
# Number of iterations: 130, function evaluations: 40, CG iterations: 351, optimality: 9.92e-03, constraint violation: 0.00e+00, execution time:  2.3 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 130, function evaluations: 36, CG iterations: 352, optimality: 4.41e-01, constraint violation: 0.00e+00, execution time:  2.0 s.
# Step 1:[0.2  0.98 0.1 ]
# Step 2:[0.2  0.98 0.1 ]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.31 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.34 s.
# Step 1:[0.36]
# Step 2:[0.36]
# `xtol` termination condition is satisfied.
# Number of iterations: 130, function evaluations: 44, CG iterations: 243, optimality: 1.86e-02, constraint violation: 0.00e+00, execution time:  2.5 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 130, function evaluations: 36, CG iterations: 352, optimality: 4.70e-01, constraint violation: 0.00e+00, execution time:  1.7 s.
# Step 1:[0.2  0.98 0.1 ]
# Step 2:[0.2  0.98 0.1 ]
# ['$\\hat\\lambda$', '$\\rho$', '$\\sigma$', '$\\hat\\lambda$', '$\\rho$', '$\\sigma$']
# NI
# 1
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((0, 3), (0, 3))
# <numba.experimental.jitclass.boxing.NoisyInformationAR object at 0x0000020C47C99C10>
# horizon 12
# ['FE', 'FEVar', 'FEATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 17, function evaluations: 30, CG iterations: 16, optimality: 7.70e-09, constraint violation: 0.00e+00, execution time:  7.7 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 23, function evaluations: 42, CG iterations: 22, optimality: 4.38e-09, constraint violation: 0.00e+00, execution time: 1.1e+01 s.
# Step 1:[3.   2.21]
# Step 2:[3.   1.15]
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 1247, function evaluations: 6945, CG iterations: 1857, optimality: 6.04e-05, constraint violation: 0.00e+00, execution time: 1.9e+03 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 644, function evaluations: 4110, CG iterations: 1270, optimality: 1.56e-03, constraint violation: 0.00e+00, execution time: 1.1e+03 s.
# Step 1:[2.82 2.93 1.   0.  ]
# Step 2:[2.87 2.99 1.   0.01]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 16, function evaluations: 33, CG iterations: 15, optimality: 6.77e-09, constraint violation: 0.00e+00, execution time:  7.5 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 68, function evaluations: 243, CG iterations: 71, optimality: 4.85e-07, constraint violation: 0.00e+00, execution time: 6.2e+01 s.
# Step 1:[3. 3.]
# Step 2:[1.35 3.  ]
# `xtol` termination condition is satisfied.
# Number of iterations: 368, function evaluations: 2695, CG iterations: 831, optimality: 1.21e-04, constraint violation: 0.00e+00, execution time: 7.2e+02 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 395, function evaluations: 2800, CG iterations: 785, optimality: 2.09e-03, constraint violation: 0.00e+00, execution time: 7.5e+02 s.
# Step 1:[2.88 2.71 1.   0.  ]
# Step 2:[2.85 2.99 1.   0.01]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 16, function evaluations: 33, CG iterations: 16, optimality: 7.32e-09, constraint violation: 0.00e+00, execution time:  7.6 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 27, function evaluations: 54, CG iterations: 30, optimality: 3.47e-09, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# Step 1:[3. 3.]
# Step 2:[1.36 3.  ]
# `xtol` termination condition is satisfied.
# Number of iterations: 289, function evaluations: 1995, CG iterations: 604, optimality: 2.38e-07, constraint violation: 0.00e+00, execution time: 5.5e+02 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 7855, CG iterations: 2138, optimality: 9.32e-02, constraint violation: 0.00e+00, execution time: 2.2e+03 s.
# the 2-step estimation is nan
# Step 1:[2.99 2.99 1.   0.  ]
# Step 2:[nan]
# ['$\\hat\\sigma_{pb}$', '$\\hat\\sigma_{pr}$', '$\\rho$', '$\\sigma$', '$\\hat\\sigma_{pb}$', '$\\hat\\sigma_{pr}$', 'NI: $\\rho$', 'NI: $\\sigma$']
# DE
# 2
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((-2, 2), (0, 5))
# <numba.experimental.jitclass.boxing.DiagnosticExpectationAR object at 0x0000020C4A060520>
# horizon 12
# ['FE', 'FEVar', 'FEATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 22, function evaluations: 36, CG iterations: 13, optimality: 2.67e-09, constraint violation: 0.00e+00, execution time: 0.15 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 85, function evaluations: 273, CG iterations: 134, optimality: 1.29e-06, constraint violation: 0.00e+00, execution time: 0.58 s.
# Step 1:[-0.8   2.51]
# Step 2:[-0.61  0.8 ]
# `xtol` termination condition is satisfied.
# Number of iterations: 326, function evaluations: 2185, CG iterations: 930, optimality: 4.50e-06, constraint violation: 0.00e+00, execution time:  3.0 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 162, function evaluations: 1050, CG iterations: 405, optimality: 1.56e-04, constraint violation: 0.00e+00, execution time:  1.2 s.
# Step 1:[-1.    1.49  1.    0.  ]
# Step 2:[-0.68  0.38  0.99  0.09]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 27, function evaluations: 60, CG iterations: 24, optimality: 6.08e-09, constraint violation: 0.00e+00, execution time: 0.16 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 93, function evaluations: 285, CG iterations: 132, optimality: 1.23e-06, constraint violation: 0.00e+00, execution time: 0.51 s.
# Step 1:[-0.87  2.76]
# Step 2:[-0.59  1.96]
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 7500, CG iterations: 5993, optimality: 3.65e-02, constraint violation: 0.00e+00, execution time: 1.5e+01 s.
# the estimation is nan
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 147, CG iterations: 76, optimality: 1.95e-08, constraint violation: 0.00e+00, execution time: 0.29 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 60, function evaluations: 135, CG iterations: 90, optimality: 5.59e-08, constraint violation: 0.00e+00, execution time: 0.29 s.
# Step 1:[0.35 3.41]
# Step 2:[0.74 2.42]
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 7730, CG iterations: 5648, optimality: 3.70e-05, constraint violation: 0.00e+00, execution time: 1.4e+01 s.
# the estimation is nan
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\theta$', '$\\sigma_\\theta$', '$\\rho$', '$\\sigma$', '$\\hat\\theta$', '$\\sigma_\\theta$', '$\\rho$', '$\\sigma$']
# DENI
# 3
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((-3, 3), (0, 3))
# <numba.experimental.jitclass.boxing.DENIHybridAR object at 0x0000020C4A1AD9A0>
# horizon 12
# ['FE', 'FEVar', 'FEATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_trustregion_constr\qp_subproblem.py:573: RuntimeWarning: invalid value encountered in scalar divide
#   alpha = rt_g / pt_H_p
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 133, function evaluations: 123, CG iterations: 133, optimality: 3.75e-02, constraint violation: 0.00e+00, execution time:  3.1 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 87, CG iterations: 2989, optimality: 5.80e-03, constraint violation: 0.00e+00, execution time:  3.9 s.
# the 2-step estimation is nan
# Step 1:[-0.66  0.7 ]
# Step 2:[nan]
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_trustregion_constr\qp_subproblem.py:616: RuntimeWarning: invalid value encountered in multiply
#   r_next = r + alpha*H_p
# `xtol` termination condition is satisfied.
# Number of iterations: 184, function evaluations: 410, CG iterations: 670, optimality: 1.28e-01, constraint violation: 0.00e+00, execution time: 1e+01 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 7500, CG iterations: 5993, optimality: 4.37e+02, constraint violation: 0.00e+00, execution time: 2e+02 s.
# the 2-step estimation is nan
# Step 1:[-0.68  1.66  1.    0.05]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 122, function evaluations: 84, CG iterations: 219, optimality: 7.11e-01, constraint violation: 0.00e+00, execution time:  2.4 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 122, function evaluations: 81, CG iterations: 219, optimality: 1.57e+00, constraint violation: 0.00e+00, execution time:  2.1 s.
# Step 1:[0.38 0.96]
# Step 2:[0.61 0.67]
# `gtol` termination condition is satisfied.
# Number of iterations: 279, function evaluations: 1430, CG iterations: 754, optimality: 1.59e-09, constraint violation: 0.00e+00, execution time: 3.4e+01 s.
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_trustregion_constr\projections.py:53: RuntimeWarning: invalid value encountered in scalar divide
#   orth = norm_A_g / (norm_A*norm_g)
# `xtol` termination condition is satisfied.
# Number of iterations: 551, function evaluations: 2260, CG iterations: 2041, optimality: 3.18e+03, constraint violation: 0.00e+00, execution time: 5.7e+01 s.
# Step 1:[-0.53  3.    1.    0.  ]
# Step 2:[0.45 1.28 0.98 0.08]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 66, function evaluations: 171, CG iterations: 80, optimality: 6.74e-10, constraint violation: 0.00e+00, execution time:  4.1 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 460, function evaluations: 1515, CG iterations: 675, optimality: 1.19e-02, constraint violation: 0.00e+00, execution time: 3.9e+01 s.
# Step 1:[-0.36  2.86]
# Step 2:[-0.12  2.24]
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 7505, CG iterations: 3128, optimality: 1.04e-01, constraint violation: 0.00e+00, execution time: 1.9e+02 s.
# the estimation is nan
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\theta$', '$\\hat\\sigma_{pr}$', '$\\rho$', '$\\sigma$', '$\\hat\\theta$', '$\\hat\\sigma_{pr}$', '$\\rho$', '$\\sigma$']
# SV
# SE
# 4
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((0, 1),)
# <numba.experimental.jitclass.boxing.StickyExpectationSV object at 0x0000020C47C993A0>
# horizon 12
# ['FE', 'FEVar', 'FEATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 55, function evaluations: 92, CG iterations: 45, optimality: 7.25e-09, constraint violation: 0.00e+00, execution time:  8.9 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 48, function evaluations: 76, CG iterations: 38, optimality: 7.15e-09, constraint violation: 0.00e+00, execution time:  7.1 s.
# Step 1:[0.26]
# Step 2:[0.28]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 55, function evaluations: 92, CG iterations: 45, optimality: 7.25e-09, constraint violation: 0.00e+00, execution time:  9.9 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time:  0.4 s.
# Step 1:[0.26]
# Step 2:[0.36]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 35, function evaluations: 52, CG iterations: 25, optimality: 7.26e-09, constraint violation: 0.00e+00, execution time:  4.8 s.
# `gtol` termination condition is satisfied.
# Number of iterations: 12, function evaluations: 6, CG iterations: 2, optimality: 5.54e-09, constraint violation: 0.00e+00, execution time: 0.53 s.
# Step 1:[0.26]
# Step 2:[0.36]
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\lambda$', '$\\gamma$']
# NI
# 5
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((0, 3), (0, 3))
# <numba.experimental.jitclass.boxing.NoisyInformationSV object at 0x0000020C49F48F70>
# horizon 12
# ['FE', 'FEVar', 'FEATV']
# Step 1
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 4488, CG iterations: 1495, optimality: 2.62e-03, constraint violation: 0.00e+00, execution time: 1.7e+03 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 4488, CG iterations: 1495, optimality: 2.62e-03, constraint violation: 0.00e+00, execution time: 1.4e+03 s.
# the estimation is nan
# Step 1:[nan]
# Step 2:[nan]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `gtol` termination condition is satisfied.
# Number of iterations: 46, function evaluations: 108, CG iterations: 36, optimality: 4.92e-09, constraint violation: 0.00e+00, execution time: 3.4e+01 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 4491, CG iterations: 1496, optimality: 9.72e-03, constraint violation: 0.00e+00, execution time: 1.4e+03 s.
# the 2-step estimation is nan
# Step 1:[0.69 0.02]
# Step 2:[nan]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 43, function evaluations: 90, CG iterations: 32, optimality: 5.04e-09, constraint violation: 0.00e+00, execution time: 2.8e+01 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 4494, CG iterations: 1496, optimality: 9.66e-03, constraint violation: 0.00e+00, execution time: 1.3e+03 s.
# the 2-step estimation is nan
# Step 1:[0.7  0.02]
# Step 2:[nan]
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\sigma_{pb}$', '$\\hat\\sigma_{pr}$', '$\\gamma$']
# DE
# 6
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((-2, 2), (0, inf))
# <numba.experimental.jitclass.boxing.DiagnosticExpectationSV object at 0x0000020C47C6FDC0>
# horizon 12
# ['FE', 'FEVar', 'FEATV']
# Step 1
# `gtol` termination condition is satisfied.
# Number of iterations: 27, function evaluations: 54, CG iterations: 24, optimality: 8.69e-09, constraint violation: 0.00e+00, execution time:  1.7 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 63, function evaluations: 126, CG iterations: 88, optimality: 2.34e-07, constraint violation: 0.00e+00, execution time:  4.4 s.
# Step 1:[-0.3   0.99]
# Step 2:[-0.28  0.66]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# `xtol` termination condition is satisfied.
# Number of iterations: 71, function evaluations: 201, CG iterations: 89, optimality: 3.54e-08, constraint violation: 0.00e+00, execution time:  6.5 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 67, function evaluations: 159, CG iterations: 102, optimality: 1.56e-07, constraint violation: 0.00e+00, execution time:  5.2 s.
# Step 1:[-0.31  0.25]
# Step 2:[-0.28  0.18]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 75, function evaluations: 219, CG iterations: 88, optimality: 4.08e-08, constraint violation: 0.00e+00, execution time:  7.6 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 66, function evaluations: 171, CG iterations: 100, optimality: 1.56e-07, constraint violation: 0.00e+00, execution time:  5.8 s.
# Step 1:[-0.31  0.25]
# Step 2:[-0.28  0.18]
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\theta$', '$\\sigma_\\theta$', '$\\gamma$']
# DENI
# 7
# 2-step estimation uses algorithmtrust-constr
# bounds for parameters((-3, 3), (0, 3))
# <numba.experimental.jitclass.boxing.DENIHybridSV object at 0x0000020C49A9D040>
# horizon 12
# ['FE', 'FEVar', 'FEATV']
# Step 1
# `xtol` termination condition is satisfied.
# Number of iterations: 116, function evaluations: 21, CG iterations: 104, optimality: 6.12e-01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# `xtol` termination condition is satisfied.
# Number of iterations: 121, function evaluations: 12, CG iterations: 110, optimality: 7.07e+00, constraint violation: 0.00e+00, execution time:  5.5 s.
# Step 1:[-0.9   0.49]
# Step 2:[-0.48  0.63]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV']
# Step 1
# C:\Program Files\Anaconda3\lib\site-packages\scipy\optimize\_numdiff.py:576: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 21, CG iterations: 2989, optimality: 1.93e-01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 21, CG iterations: 2989, optimality: 1.93e-01, constraint violation: 0.00e+00, execution time: 1.2e+01 s.
# the estimation is nan
# Step 1:[nan]
# Step 2:[nan]
# Step 1:[nan]
# Step 2:[nan]
# ['FE', 'FEVar', 'FEATV', 'Disg', 'DisgVar', 'DisgATV', 'Var', 'VarVar', 'VarATV']
# Step 1
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 21, CG iterations: 2989, optimality: 1.71e-01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# The maximum number of function evaluations is exceeded.
# Number of iterations: 1500, function evaluations: 21, CG iterations: 2989, optimality: 1.71e-01, constraint violation: 0.00e+00, execution time: 1.3e+01 s.
# the estimation is nan
# Step 1:[nan]
# Step 2:[nan]
# Step 1:[nan]
# Step 2:[nan]
# ['$\\hat\\theta$', '$\\hat\\sigma_{pr}$', '$\\gamma$']

# %%
## create multiple index to store coefficient estimates 

iterables = [agents_list, process_list, ex_model_list,moments_list_general]
midx = pd.MultiIndex.from_product(iterables, names=['Agents', 'Process','Model','Moments'])
paras_table = pd.DataFrame(index = midx)

## 2-step table
paras_list = [tuple(paras) for paras in paras_list]
paras_table['ParaEst'] = paras_list

paras_step2_list = [tuple(paras) for paras in paras_step2_list]
paras_table['ParaEst2step'] = paras_step2_list

## joint table
paras_joint_table = pd.DataFrame(index = midx)

paras_joint_list = [tuple(paras) for paras in paras_joint_list]
paras_joint_table['ParaEst'] = paras_joint_list

paras_joint_step2_list = [tuple(paras) for paras in paras_joint_step2_list]
paras_joint_table['ParaEst2step'] = paras_joint_step2_list

# %%
paras_table.columns = [['2-step Estimate',
                        '2-step Estimate 2nd step']]
paras_joint_table.columns = [['Joint Estimate',
                              'Joint Estimate 2nd step']]

# %%
paras_combine_table = pd.merge(paras_table,
                               paras_joint_table,
                               how='outer',
                               left_index=True,
                               right_index=True)

# %%
print(process_paraQ_est_ar)
print(process_paraM_est_ar)
# Out:
# [1.         0.44451311]
# [0.99211181 0.46098669]

# %%
paras_combine_table
# Out:
#                                  2-step Estimate 2-step Estimate 2nd step  \
# Agents Process Model Moments
# SPF    AR      SE    FE                  (0.36,)                  (0.27,)
#                      FE+Disg             (0.36,)                  (0.26,)
#                      FE+Disg+Var         (0.36,)                  (0.36,)
#                NI    FE             (2.99, 0.04)              (2.98, 0.0)
#                      FE+Disg         (0.0, 0.82)              (0.03, 0.8)
#                      FE+Disg+Var     (0.0, 0.84)             (0.03, 0.85)
#                DE    FE              (0.12, 1.9)             (0.47, 0.52)
#                      FE+Disg        (0.55, 2.13)             (0.73, 2.17)
#                      FE+Disg+Var    (0.54, 2.13)             (0.69, 2.17)
#                DENI  FE              (0.82, 0.0)             (0.65, 0.49)
#                      FE+Disg        (0.21, 0.35)             (0.21, 0.35)
#                      FE+Disg+Var    (0.83, 0.17)             (0.87, 0.15)
#        SV      SE    FE                  (0.26,)                  (0.25,)
#                      FE+Disg             (0.27,)                  (0.29,)
#                      FE+Disg+Var         (0.27,)                  (0.28,)
#                NI    FE              (2.15, 3.0)              (1.03, 3.0)
#                      FE+Disg         (2.14, 3.0)              (1.03, 3.0)
#                      FE+Disg+Var     (2.14, 3.0)              (2.02, 3.0)
#                DE    FE             (0.05, 0.48)              (0.06, 0.5)
#                      FE+Disg        (0.05, 0.16)             (0.06, 0.16)
#                      FE+Disg+Var    (0.05, 0.16)             (0.06, 0.16)
#                DENI  FE             (0.85, 1.86)             (0.58, 0.83)
#                      FE+Disg        (0.82, 1.92)             (0.76, 0.83)
#                      FE+Disg+Var    (0.81, 1.91)               (0.6, 0.8)
# SCE    AR      SE    FE                  (0.36,)                  (0.36,)
#                      FE+Disg             (0.36,)                  (0.36,)
#                      FE+Disg+Var         (0.36,)                  (0.36,)
#                NI    FE              (3.0, 2.21)              (3.0, 1.15)
#                      FE+Disg          (3.0, 3.0)              (1.35, 3.0)
#                      FE+Disg+Var      (3.0, 3.0)              (1.36, 3.0)
#                DE    FE             (-0.8, 2.51)             (-0.61, 0.8)
#                      FE+Disg       (-0.87, 2.76)            (-0.59, 1.96)
#                      FE+Disg+Var    (0.35, 3.41)             (0.74, 2.42)
#                DENI  FE             (-0.66, 0.7)                   (nan,)
#                      FE+Disg        (0.38, 0.96)             (0.61, 0.67)
#                      FE+Disg+Var   (-0.36, 2.86)            (-0.12, 2.24)
#        SV      SE    FE                  (0.26,)                  (0.28,)
#                      FE+Disg             (0.26,)                  (0.36,)
#                      FE+Disg+Var         (0.26,)                  (0.36,)
#                NI    FE                   (nan,)                   (nan,)
#                      FE+Disg        (0.69, 0.02)                   (nan,)
#                      FE+Disg+Var     (0.7, 0.02)                   (nan,)
#                DE    FE             (-0.3, 0.99)            (-0.28, 0.66)
#                      FE+Disg       (-0.31, 0.25)            (-0.28, 0.18)
#                      FE+Disg+Var   (-0.31, 0.25)            (-0.28, 0.18)
#                DENI  FE             (-0.9, 0.49)            (-0.48, 0.63)
#                      FE+Disg              (nan,)                   (nan,)
#                      FE+Disg+Var          (nan,)                   (nan,)
#
#                                             Joint Estimate  \
# Agents Process Model Moments
# SPF    AR      SE    FE                 (0.51, 0.99, 0.04)
#                      FE+Disg            (0.24, 0.99, 0.03)
#                      FE+Disg+Var         (0.5, 0.99, 0.04)
#                NI    FE            (0.0, 0.23, 0.99, 0.04)
#                      FE+Disg       (0.0, 0.18, 0.99, 0.04)
#                      FE+Disg+Var    (0.0, 0.2, 0.98, 0.05)
#                DE    FE           (0.52, 0.75, 0.98, 0.05)
#                      FE+Disg      (0.53, 2.13, 0.98, 0.05)
#                      FE+Disg+Var  (0.72, 2.15, 0.98, 0.06)
#                DENI  FE            (0.79, 0.0, 0.98, 0.05)
#                      FE+Disg       (0.8, 0.15, 0.98, 0.05)
#                      FE+Disg+Var   (0.8, 0.15, 0.98, 0.06)
#        SV      SE    FE                             (nan,)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
#                NI    FE                             (nan,)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
#                DE    FE                             (nan,)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
#                DENI  FE                             (nan,)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
# SCE    AR      SE    FE                   (0.25, 1.0, 0.0)
#                      FE+Disg              (0.2, 0.98, 0.1)
#                      FE+Disg+Var          (0.2, 0.98, 0.1)
#                NI    FE             (2.82, 2.93, 1.0, 0.0)
#                      FE+Disg        (2.88, 2.71, 1.0, 0.0)
#                      FE+Disg+Var    (2.99, 2.99, 1.0, 0.0)
#                DE    FE             (-1.0, 1.49, 1.0, 0.0)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
#                DENI  FE           (-0.68, 1.66, 1.0, 0.05)
#                      FE+Disg        (-0.53, 3.0, 1.0, 0.0)
#                      FE+Disg+Var                    (nan,)
#        SV      SE    FE                             (nan,)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
#                NI    FE                             (nan,)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
#                DE    FE                             (nan,)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
#                DENI  FE                             (nan,)
#                      FE+Disg                        (nan,)
#                      FE+Disg+Var                    (nan,)
#
#                                     Joint Estimate 2nd step
# Agents Process Model Moments
# SPF    AR      SE    FE                   (0.19, 1.0, 0.02)
#                      FE+Disg               (0.2, 0.98, 0.1)
#                      FE+Disg+Var           (0.2, 0.98, 0.1)
#                NI    FE             (0.0, 0.16, 0.99, 0.04)
#                      FE+Disg        (0.0, 0.19, 0.99, 0.04)
#                      FE+Disg+Var    (0.0, 0.19, 0.99, 0.05)
#                DE    FE             (0.71, 0.4, 0.98, 0.05)
#                      FE+Disg       (0.69, 2.17, 0.98, 0.05)
#                      FE+Disg+Var                     (nan,)
#                DENI  FE              (0.8, 0.0, 0.99, 0.05)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#        SV      SE    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                NI    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DE    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DENI  FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
# SCE    AR      SE    FE                   (0.18, 1.0, 0.03)
#                      FE+Disg               (0.2, 0.98, 0.1)
#                      FE+Disg+Var           (0.2, 0.98, 0.1)
#                NI    FE             (2.87, 2.99, 1.0, 0.01)
#                      FE+Disg        (2.85, 2.99, 1.0, 0.01)
#                      FE+Disg+Var                     (nan,)
#                DE    FE           (-0.68, 0.38, 0.99, 0.09)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DENI  FE                              (nan,)
#                      FE+Disg       (0.45, 1.28, 0.98, 0.08)
#                      FE+Disg+Var                     (nan,)
#        SV      SE    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                NI    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DE    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DENI  FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)

# %%
## only 2nd-step estimates 

paras_combine_table_2step = paras_combine_table[['2-step Estimate 2nd step','Joint Estimate 2nd step']]

paras_combine_table_2step
# Out:
#                                  2-step Estimate 2nd step  \
# Agents Process Model Moments
# SPF    AR      SE    FE                           (0.27,)
#                      FE+Disg                      (0.26,)
#                      FE+Disg+Var                  (0.36,)
#                NI    FE                       (2.98, 0.0)
#                      FE+Disg                  (0.03, 0.8)
#                      FE+Disg+Var             (0.03, 0.85)
#                DE    FE                      (0.47, 0.52)
#                      FE+Disg                 (0.73, 2.17)
#                      FE+Disg+Var             (0.69, 2.17)
#                DENI  FE                      (0.65, 0.49)
#                      FE+Disg                 (0.21, 0.35)
#                      FE+Disg+Var             (0.87, 0.15)
#        SV      SE    FE                           (0.25,)
#                      FE+Disg                      (0.29,)
#                      FE+Disg+Var                  (0.28,)
#                NI    FE                       (1.03, 3.0)
#                      FE+Disg                  (1.03, 3.0)
#                      FE+Disg+Var              (2.02, 3.0)
#                DE    FE                       (0.06, 0.5)
#                      FE+Disg                 (0.06, 0.16)
#                      FE+Disg+Var             (0.06, 0.16)
#                DENI  FE                      (0.58, 0.83)
#                      FE+Disg                 (0.76, 0.83)
#                      FE+Disg+Var               (0.6, 0.8)
# SCE    AR      SE    FE                           (0.36,)
#                      FE+Disg                      (0.36,)
#                      FE+Disg+Var                  (0.36,)
#                NI    FE                       (3.0, 1.15)
#                      FE+Disg                  (1.35, 3.0)
#                      FE+Disg+Var              (1.36, 3.0)
#                DE    FE                      (-0.61, 0.8)
#                      FE+Disg                (-0.59, 1.96)
#                      FE+Disg+Var             (0.74, 2.42)
#                DENI  FE                            (nan,)
#                      FE+Disg                 (0.61, 0.67)
#                      FE+Disg+Var            (-0.12, 2.24)
#        SV      SE    FE                           (0.28,)
#                      FE+Disg                      (0.36,)
#                      FE+Disg+Var                  (0.36,)
#                NI    FE                            (nan,)
#                      FE+Disg                       (nan,)
#                      FE+Disg+Var                   (nan,)
#                DE    FE                     (-0.28, 0.66)
#                      FE+Disg                (-0.28, 0.18)
#                      FE+Disg+Var            (-0.28, 0.18)
#                DENI  FE                     (-0.48, 0.63)
#                      FE+Disg                       (nan,)
#                      FE+Disg+Var                   (nan,)
#
#                                     Joint Estimate 2nd step
# Agents Process Model Moments
# SPF    AR      SE    FE                   (0.19, 1.0, 0.02)
#                      FE+Disg               (0.2, 0.98, 0.1)
#                      FE+Disg+Var           (0.2, 0.98, 0.1)
#                NI    FE             (0.0, 0.16, 0.99, 0.04)
#                      FE+Disg        (0.0, 0.19, 0.99, 0.04)
#                      FE+Disg+Var    (0.0, 0.19, 0.99, 0.05)
#                DE    FE             (0.71, 0.4, 0.98, 0.05)
#                      FE+Disg       (0.69, 2.17, 0.98, 0.05)
#                      FE+Disg+Var                     (nan,)
#                DENI  FE              (0.8, 0.0, 0.99, 0.05)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#        SV      SE    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                NI    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DE    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DENI  FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
# SCE    AR      SE    FE                   (0.18, 1.0, 0.03)
#                      FE+Disg               (0.2, 0.98, 0.1)
#                      FE+Disg+Var           (0.2, 0.98, 0.1)
#                NI    FE             (2.87, 2.99, 1.0, 0.01)
#                      FE+Disg        (2.85, 2.99, 1.0, 0.01)
#                      FE+Disg+Var                     (nan,)
#                DE    FE           (-0.68, 0.38, 0.99, 0.09)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DENI  FE                              (nan,)
#                      FE+Disg       (0.45, 1.28, 0.98, 0.08)
#                      FE+Disg+Var                     (nan,)
#        SV      SE    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                NI    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DE    FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)
#                DENI  FE                              (nan,)
#                      FE+Disg                         (nan,)
#                      FE+Disg+Var                     (nan,)

# %%
## Flag those under-identified cases 

ui_list = [('SPF','AR','NI','FE'),
          ('SCE','AR','NI','FE'),
          ('SPF','AR','DENI','FE'),
          ('SCE','AR','DENI','FE'),
          ('SPF','SV','NI','FE'),
          ('SCE','SV','NI','FE'),
          ('SPF','SV','DENI','FE'),
          ('SCE','SV','DENI','FE')
          ]


for case in ui_list:
    print(case)
    for name in paras_combine_table.columns:
        print(name)
        paras_combine_table.loc[case,name]= tuple(np.array([]))
        #paras_combine_table.loc[case][name] = tuple(np.array([]))
# Out:
# ('SPF', 'AR', 'NI', 'FE')
# ('2-step Estimate',)
# C:\Users\want\AppData\Local\Temp\ipykernel_18284\2813330448.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   paras_combine_table.loc[case,name]= tuple(np.array([]))
# ('2-step Estimate 2nd step',)
# ('Joint Estimate',)
# ('Joint Estimate 2nd step',)
# ('SCE', 'AR', 'NI', 'FE')
# ('2-step Estimate',)
# ('2-step Estimate 2nd step',)
# ('Joint Estimate',)
# ('Joint Estimate 2nd step',)
# ('SPF', 'AR', 'DENI', 'FE')
# ('2-step Estimate',)
# ('2-step Estimate 2nd step',)
# ('Joint Estimate',)
# ('Joint Estimate 2nd step',)
# ('SCE', 'AR', 'DENI', 'FE')
# ('2-step Estimate',)
# ('2-step Estimate 2nd step',)
# ('Joint Estimate',)
# ('Joint Estimate 2nd step',)
# ('SPF', 'SV', 'NI', 'FE')
# ('2-step Estimate',)
# ('2-step Estimate 2nd step',)
# ('Joint Estimate',)
# ('Joint Estimate 2nd step',)
# ('SCE', 'SV', 'NI', 'FE')
# ('2-step Estimate',)
# ('2-step Estimate 2nd step',)
# ('Joint Estimate',)
# ('Joint Estimate 2nd step',)
# ('SPF', 'SV', 'DENI', 'FE')
# ('2-step Estimate',)
# ('2-step Estimate 2nd step',)
# ('Joint Estimate',)
# ('Joint Estimate 2nd step',)
# ('SCE', 'SV', 'DENI', 'FE')
# ('2-step Estimate',)
# ('2-step Estimate 2nd step',)
# ('Joint Estimate',)
# ('Joint Estimate 2nd step',)

# %%
t_sim = 500
t_burn = 30

def simulate_history(pg_para,
                     t_sim,
                     t_burn):
    if len(pg_para)==2:
        ρ,σ = pg_para
        history_this = SimAR1(ρ,
                              σ,
                              t_sim)
        real_time_this = history_this[t_burn:-2] 
        realized_this = history_this[t_burn+1:-1]
        
    elif len(pg_para)==1:
        γ_fake = pg_para[0]
        
        
        history_this,p_history_this,vol_p_history_this,vol_t_history_this = SimUCSV(γ_fake,
                                                                                    nobs = t_sim,
                                                                                    p0 = p0_fake) 
        history_this =  np.array([history_this,
                                p_history_this,
                                vol_p_history_this,
                                vol_t_history_this]
                               )

        real_time_this = history_this[:,t_burn:-2]
        realized_this = history_this[0,t_burn+1:-1] ## notice, just Y itself is 
        
    return realized_this,history_this,real_time_this

# %%
## generate model moments

smm_list = []
smm_joint_list = []
smm_ts_list = []

for agent_id,agent in enumerate(agents_list):
    print(agent)
    realized_this = realized_list[agent_id]
    data_mom_dict_this = data_mom_dict_list[agent_id]

    for pg_id,process in enumerate(process_list):
        print(process)
        process_paras_this = process_paras_list[agent_process_id]
        
        ## history and real-time inflation that is fed in the model depends on agent type and process
        agent_process_id = agent_id*2+pg_id       
        
        process_paras_this = process_paras_list[agent_process_id]
        real_time_this = real_time_list[agent_process_id]
        history_this = history_list[agent_process_id]
        
        for exp_id,ex_model in enumerate(ex_model_list):
            n_exp_model = len(ex_model_list)
            print(ex_model)
            model_idx  = pg_id*n_exp_model+exp_id
            #print(model_idx)
            instance = model_list[model_idx]
            print(instance)
            
            ## directly use the history 
            instance.GetRealization(realized_this)   
            instance.history = history_this
            instance.real_time = real_time_this
            print("Length of real time series is "+str(len(instance.real_time)))
            
            ## compute moments with these parameters 
            for moments in moments_list_general:
                ## 2-step moments 
                para_est_this = np.array(list(paras_combine_table.loc[agent,process,ex_model,moments]['2-step Estimate 2nd step'])).flatten()
                print(para_est_this)
                print(process_paras_this)
                
                try:
                    instance.process_para = process_paras_this
                    instance.exp_para = para_est_this
                    smm_ts_this = instance.SimForecasts()
                    print('Length of simulated moments is '+str(len(smm_ts_this['FE'])))
                    smm_this = instance.SMM()
                    print(smm_this)

                except:
                    print('failed')
                    smm_this = {}
                    smm_ts_this = {"Forecast":np.nan,
                                  "FE":np.nan,
                                  'Disg':np.nan,
                                  'Var':np.nan}
                smm_list.append(smm_this)
                smm_ts_list.append(smm_ts_this)

                ## joint moments
                n_exp_paras_this = n_exp_paras_list[exp_id]
                para_est_this_ = np.array(list(paras_combine_table.loc[agent,process,ex_model,moments]['Joint Estimate 2nd step'])).flatten()
                print(para_est_this_)
                try:
                    instance.exp_para = para_est_this_[0:n_exp_paras_this]     
                    instance.process_para = para_est_this_[n_exp_paras_this:]
                    
                    try:
                        smm_this = instance.SMM()
                        print(smm_this)
                        smm_joint_list.append(smm_this)
                    except:
                        smm_this = {}
                        smm_joint_list.append(smm_this)
                except:
                    smm_this = {}
                    smm_joint_list.append(smm_this)
# Out:
# SPF
# AR
# SE
# <numba.experimental.jitclass.boxing.StickyExpectationAR object at 0x0000020C411E4A30>
# Length of real time series is 13
# [0.27]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.041189956435888, FE: 0.19797117137001735, FEVar: 0.1724353895592832, FEATV: nan, Disg: 0.03640743577793422, DisgVar: 0.00013611020116565715, DisgATV: nan, Var: 2.9075800475819262, VarVar: 0.0003307112751967988, VarATV: nan}
# [0.19 1.   0.02]
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.020826904797472, FE: 0.17760811973160084, FEVar: 0.1702123852031354, FEATV: nan, Disg: 0.04374637467205343, DisgVar: 9.089599904924806e-05, DisgATV: nan, Var: 0.006447876923076903, VarVar: 1.0498802366863835e-09, VarATV: nan}
# [0.26]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.0379463123000146, FE: 0.19472752723414358, FEVar: 0.17148484589489235, FEATV: nan, Disg: 0.037167131357947775, DisgVar: 0.00012796309574391107, DisgATV: nan, Var: 2.9325374248304286, VarVar: 0.00013820789018939786, VarATV: nan}
# [0.2  0.98 0.1 ]
# {InfAV: 0.0, InfVar: 0.25252525252525204, InfATV: 0.19816078882191873, Forecast: 1.4790599597491545, FE: -0.36415882531671656, FEVar: 0.16961508262143177, FEATV: nan, Disg: 0.047101706799513796, DisgVar: 0.00018483406288921596, DisgATV: nan, Var: 0.11757968926404785, VarVar: 1.0762224436266689e-07, VarATV: nan}
# [0.36]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.054356207229418, FE: 0.2111374221635468, FEVar: 0.17786996773238564, FEATV: nan, Disg: 0.029079270455155886, DisgVar: 0.00021937437607484538, DisgATV: nan, Var: 2.7109609050200345, VarVar: 0.0002719764795907136, VarATV: nan}
# [0.2  0.98 0.1 ]
# {InfAV: 0.0, InfVar: 0.25252525252525204, InfATV: 0.19816078882191873, Forecast: 1.4790599597491545, FE: -0.36415882531671656, FEVar: 0.16961508262143177, FEATV: nan, Disg: 0.047101706799513796, DisgVar: 0.00018483406288921596, DisgATV: nan, Var: 0.11757968926404785, VarVar: 1.0762224436266689e-07, VarATV: nan}
# NI
# <numba.experimental.jitclass.boxing.NoisyInformationAR object at 0x0000020C47C99C10>
# Length of real time series is 13
# []
# [1.         0.44451311]
# failed
# []
# [0.03 0.8 ]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.0851625593759713, FE: 0.24194377431010045, FEVar: 0.19421394682472087, FEATV: nan, Disg: 1.2279695174547108e-06, DisgVar: 5.7425130385696095e-15, DisgATV: nan, Var: 2.371997517447432, VarVar: 1.9721522630525295e-31, VarATV: nan}
# [0.   0.19 0.99 0.04]
# {InfAV: 0.0, InfVar: 0.08040201005025115, InfATV: 0.07126712536411078, Forecast: 1.8376105862044239, FE: -0.0056081988614470075, FEVar: 0.18318617665675135, FEATV: nan, Disg: 1.8513958629456207e-28, DisgVar: 1.8376646563572152e-56, DisgATV: nan, Var: 0.01723190827680651, VarVar: 1.2037062152420224e-35, VarATV: nan}
# [0.03 0.85]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.085165693177002, FE: 0.24194690811113137, FEVar: 0.19421476773524843, FEATV: nan, Disg: 1.0880989021766882e-06, DisgVar: 4.508824881990338e-15, DisgATV: nan, Var: 2.3719976602890265, VarVar: 1.9721522630525295e-31, VarATV: nan}
# [0.   0.19 0.99 0.05]
# {InfAV: 0.0, InfVar: 0.12562814070351744, InfATV: 0.11135488338142312, Forecast: 1.8376105862044239, FE: -0.0056081988614470075, FEVar: 0.18318617665675135, FEATV: nan, Disg: 1.8513958629456207e-28, DisgVar: 1.8376646563572152e-56, DisgATV: nan, Var: 0.026924856682510382, VarVar: 0.0, VarATV: nan}
# DE
# <numba.experimental.jitclass.boxing.DiagnosticExpectationAR object at 0x0000020C4A060520>
# Length of real time series is 13
# [0.47 0.52]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.080335331155145, FE: 0.23711654608927396, FEVar: 0.19447477022499926, FEATV: nan, Disg: 0.01015039829748777, DisgVar: 0.0001634590384201708, DisgATV: nan, Var: 2.371102832379034, VarVar: 1.9721522630525295e-31, VarATV: nan}
# [0.71 0.4  0.98 0.05]
# {InfAV: 0.0, InfVar: 0.06313131313131301, InfATV: 0.04954019720547968, Forecast: 1.6582051756819294, FE: -0.18501360938394162, FEVar: 0.1807076547882197, FEATV: nan, Disg: 0.003938540816672414, DisgVar: 2.0117958416000982e-05, DisgATV: nan, Var: 0.02425629188705303, VarVar: 0.0, VarATV: nan}
# [0.73 2.17]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.084114760866299, FE: 0.24089597580042793, FEVar: 0.2031202501187982, FEATV: nan, Disg: 0.17676483188994133, DisgVar: 0.04957177851580599, DisgATV: nan, Var: 2.371102832379034, VarVar: 1.9721522630525295e-31, VarATV: nan}
# [0.69 2.17 0.98 0.05]
# {InfAV: 0.0, InfVar: 0.06313131313131301, InfATV: 0.04954019720547968, Forecast: 1.6565908257351507, FE: -0.18662795933072057, FEVar: 0.18003797522406964, FEATV: nan, Disg: 0.11591371782267952, DisgVar: 0.017425404818516795, DisgATV: nan, Var: 0.02425629188705303, VarVar: 0.0, VarATV: nan}
# [0.69 2.17]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.083497102769304, FE: 0.24027831770343328, FEVar: 0.20141067075778168, FEATV: nan, Disg: 0.1767648318899414, DisgVar: 0.049571778515806034, DisgATV: nan, Var: 2.371102832379034, VarVar: 1.9721522630525295e-31, VarATV: nan}
# [nan]
# DENI
# <numba.experimental.jitclass.boxing.DENIHybridAR object at 0x0000020C4A1AD9A0>
# Length of real time series is 13
# []
# [1.         0.44451311]
# failed
# []
# [0.21 0.35]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.0835196030812315, FE: 0.2403008180153608, FEVar: 0.18954541047652537, FEATV: nan, Disg: 0.19914036122304354, DisgVar: 0.00011066620409514798, DisgATV: nan, Var: 2.3665385249437394, VarVar: 1.9721522630525295e-31, VarATV: nan}
# [nan]
# [0.87 0.15]
# [1.         0.44451311]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.076255659326775, FE: 0.23303687426090386, FEVar: 0.1593855585552066, FEATV: nan, Disg: 0.3355690477386093, DisgVar: 0.00010784602120507673, DisgATV: nan, Var: 2.3702320999552735, VarVar: 0.0, VarATV: nan}
# [nan]
# SV
# SE
# <numba.experimental.jitclass.boxing.StickyExpectationSV object at 0x0000020C47C993A0>
# Length of real time series is 4
# [0.25]
# [0.2]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 3.3359284677175114, FE: 1.4927096826516408, FEVar: 1.7203331241639186, FEATV: nan, Disg: 1.3233348523677908, DisgVar: 1.29611638058127, DisgATV: nan, Var: 0.341531499786582, VarVar: 0.045078294719586035, VarATV: nan}
# [nan]
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 1.4942511425737188, FE: -0.3489676424921525, FEVar: 0.17017723889869765, FEATV: nan, Disg: 5.369184536160512e-29, DisgVar: 0.0, DisgATV: nan, Var: nan, VarVar: nan, VarATV: nan}
# [0.29]
# [0.2]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 3.4522715922187404, FE: 1.6090528071528694, FEVar: 1.9839107868761456, FEATV: nan, Disg: 1.1643382298739797, DisgVar: 0.9967809924970711, DisgATV: nan, Var: 0.360985972516184, VarVar: 0.04857994885626207, VarATV: nan}
# [nan]
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 1.4942511425737188, FE: -0.3489676424921525, FEVar: 0.17017723889869765, FEATV: nan, Disg: 5.369184536160512e-29, DisgVar: 0.0, DisgATV: nan, Var: nan, VarVar: nan, VarATV: nan}
# [0.28]
# [0.2]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 3.4186629881037476, FE: 1.5754442030378768, FEVar: 1.8974299378745239, FEATV: nan, Disg: 1.2174056749146476, DisgVar: 1.0815157889898803, DisgATV: nan, Var: 0.35681024387210447, VarVar: 0.04769573433478924, VarATV: nan}
# [nan]
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 1.4942511425737188, FE: -0.3489676424921525, FEVar: 0.17017723889869765, FEATV: nan, Disg: 5.369184536160512e-29, DisgVar: 0.0, DisgATV: nan, Var: nan, VarVar: nan, VarATV: nan}
# NI
# <numba.experimental.jitclass.boxing.NoisyInformationSV object at 0x0000020C49F48F70>
# Length of real time series is 4
# []
# [0.2]
# failed
# []
# [1.03 3.  ]
# [0.2]
# Length of simulated moments is 13
# {InfAV: nan, InfVar: nan, InfATV: nan, Forecast: 2.073791776949345, FE: 0.2305729918834736, FEVar: 0.191122883053223, FEATV: nan, Disg: 4.467571194122083e-07, DisgVar: 6.017480246837033e-14, DisgATV: nan, Var: 0.4486515518776309, VarVar: 0.047852123665286746, VarATV: nan}
# [nan]
# [2.02 3.  ]
# [0.2]
# Length of simulated moments is 13
# {InfAV: nan, InfVar: nan, InfATV: nan, Forecast: 2.073791776949345, FE: 0.2305729918834736, FEVar: 0.191122883053223, FEATV: nan, Disg: 4.467571194122083e-07, DisgVar: 6.017480246837033e-14, DisgATV: nan, Var: 0.4486515518776309, VarVar: 0.047852123665286746, VarATV: nan}
# [nan]
# DE
# <numba.experimental.jitclass.boxing.DiagnosticExpectationSV object at 0x0000020C47C6FDC0>
# Length of real time series is 4
# [0.06 0.5 ]
# [0.2]
# Length of simulated moments is 13
# {InfAV: nan, InfVar: nan, InfATV: nan, Forecast: 1.978630991948208, FE: 0.13541220688233693, FEVar: 0.21216523011006844, FEATV: nan, Disg: 1.5956830072654689, DisgVar: 3.2782178076426836, DisgATV: nan, Var: 0.4467633044333068, VarVar: 0.047577473692044646, VarATV: nan}
# [nan]
# [0.06 0.16]
# [0.2]
# Length of simulated moments is 13
# {InfAV: nan, InfVar: nan, InfATV: nan, Forecast: 1.9732707855125773, FE: 0.13005200044670603, FEVar: 0.21402593255544275, FEATV: nan, Disg: 0.16339793994398397, DisgVar: 0.034374605158667346, DisgATV: nan, Var: 0.4467633044333068, VarVar: 0.047577473692044646, VarATV: nan}
# [nan]
# [0.06 0.16]
# [0.2]
# Length of simulated moments is 13
# {InfAV: nan, InfVar: nan, InfATV: nan, Forecast: 1.9732707855125773, FE: 0.13005200044670603, FEVar: 0.21402593255544275, FEATV: nan, Disg: 0.16339793994398397, DisgVar: 0.034374605158667346, DisgATV: nan, Var: 0.4467633044333068, VarVar: 0.047577473692044646, VarATV: nan}
# [nan]
# DENI
# <numba.experimental.jitclass.boxing.DENIHybridSV object at 0x0000020C49A9D040>
# Length of real time series is 4
# []
# [0.2]
# failed
# []
# [0.76 0.83]
# [0.2]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 2.0844187348305825, FE: 0.24119994976471174, FEVar: 0.16670848933984594, FEATV: nan, Disg: 3.0247607245120734e-05, DisgVar: 3.543902035847004e-10, DisgATV: nan, Var: 0.44864624054903096, VarVar: 0.047850869788612534, VarATV: nan}
# [nan]
# [0.6 0.8]
# [0.2]
# Length of simulated moments is 13
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 2.0865316274539514, FE: 0.2433128423880802, FEVar: 0.1768531077095522, FEATV: nan, Disg: 2.0917145472873402e-05, DisgVar: 1.4860655033466663e-10, DisgATV: nan, Var: 0.4486458025131288, VarVar: 0.047850766455726355, VarATV: nan}
# [nan]
# SCE
# AR
# SE
# <numba.experimental.jitclass.boxing.StickyExpectationAR object at 0x0000020C411E4A30>
# Length of real time series is 82
# [0.36]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.40332688550228, FE: -0.12044178343523947, FEVar: 0.879304435086244, FEATV: -0.07776870427954934, Disg: 0.0892045656026375, DisgVar: 0.006325113537637942, DisgATV: 0.0012912191195190157, Var: 2.6441151394459377, VarVar: 0.00022216620626953077, VarATV: 2.749643398970938e-05}
# [0.18 1.   0.03]
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 1.5531527082197418, FE: 0.029384039282222076, FEVar: 0.9268716917305357, FEATV: 0.029319732931925618, Disg: 0.22522833126648215, DisgVar: 0.02286249915091357, DisgATV: -0.002164756435630368, Var: 0.014869865853658522, VarVar: 3.5322989321832357e-08, VarATV: 6.238586459627528e-09}
# [0.36]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.40332688550228, FE: -0.12044178343523947, FEVar: 0.879304435086244, FEATV: -0.07776870427954934, Disg: 0.0892045656026375, DisgVar: 0.006325113537637942, DisgATV: 0.0012912191195190157, Var: 2.6441151394459377, VarVar: 0.00022216620626953077, VarATV: 2.749643398970938e-05}
# [0.2  0.98 0.1 ]
# {InfAV: 0.0, InfVar: 0.25252525252525204, InfATV: 0.19816078882191873, Forecast: 1.1310865137903094, FE: -0.39268215514720994, FEVar: 0.7733903788252829, FEATV: -0.002557615486800753, Disg: 0.11488269294116178, DisgVar: 0.006205928258385509, DisgATV: -0.00032297248363544103, Var: 0.11829118536650653, VarVar: 6.862079114111754e-07, VarATV: 1.246694825586475e-07}
# [0.36]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.40332688550228, FE: -0.12044178343523947, FEVar: 0.879304435086244, FEATV: -0.07776870427954934, Disg: 0.0892045656026375, DisgVar: 0.006325113537637942, DisgATV: 0.0012912191195190157, Var: 2.6441151394459377, VarVar: 0.00022216620626953077, VarATV: 2.749643398970938e-05}
# [0.2  0.98 0.1 ]
# {InfAV: 0.0, InfVar: 0.25252525252525204, InfATV: 0.19816078882191873, Forecast: 1.1310865137903094, FE: -0.39268215514720994, FEVar: 0.7733903788252829, FEATV: -0.002557615486800753, Disg: 0.11488269294116178, DisgVar: 0.006205928258385509, DisgATV: -0.00032297248363544103, Var: 0.11829118536650653, VarVar: 6.862079114111754e-07, VarATV: 1.246694825586475e-07}
# NI
# <numba.experimental.jitclass.boxing.NoisyInformationAR object at 0x0000020C47C99C10>
# Length of real time series is 82
# []
# [0.99211181 0.46098669]
# failed
# []
# [1.35 3.  ]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.4223623079388386, FE: -0.10140636099868053, FEVar: 1.3100665314821844, FEATV: -0.020027223115970792, Disg: 0.03740028072325223, DisgVar: 5.244905016369642e-06, DisgATV: -1.0250071386727006e-06, Var: 2.7249005403905353, VarVar: 7.888609052210118e-31, VarATV: 8.002936719633454e-31}
# [2.85 2.99 1.   0.01]
# {InfAV: 0.0, InfVar: 0.0, InfATV: 0.0, Forecast: 2.43018594980357, FE: 0.9064172808660491, FEVar: 0.7852411995442736, FEATV: 0.22938205567813177, Disg: 0.003941186173183884, DisgVar: 1.077806875034245e-08, DisgATV: 2.8530897682746945e-10, Var: 0.021787081797846948, VarVar: 2.7748683659504706e-12, VarATV: 2.0281634655918518e-12}
# [1.36 3.  ]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.4221799675477589, FE: -0.10158870138976071, FEVar: 1.3119012139030393, FEATV: -0.01876397591957382, Disg: 0.03809346923627858, DisgVar: 5.433768052161769e-06, DisgATV: -1.0713949254729785e-06, Var: 2.7276490303445375, VarVar: 0.0, VarATV: 0.0}
# [nan]
# DE
# <numba.experimental.jitclass.boxing.DiagnosticExpectationAR object at 0x0000020C4A060520>
# Length of real time series is 82
# [-0.61  0.8 ]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.4237527740189002, FE: -0.10001589491861933, FEVar: 0.9359294186573262, FEATV: -0.12961465795125615, Disg: 0.052793285401976954, DisgVar: 0.005509189138952147, DisgATV: 0.0013007852432909898, Var: 2.340851287844068, VarVar: 4.930380657631324e-30, VarATV: 8.002936719633454e-31}
# [-0.68  0.38  0.99  0.09]
# {InfAV: 0.0, InfVar: 0.40703517587939636, InfATV: 0.3607898221558108, Forecast: 1.3850315524182117, FE: -0.13873711651930823, FEVar: 0.9161115392742187, FEATV: -0.123963258955618, Disg: 0.011307683429100117, DisgVar: 0.00025085563312057866, DisgATV: 6.077597829929675e-05, Var: 0.0872365356513336, VarVar: 1.560003254953661e-32, VarATV: 7.03383110124034e-33}
# [-0.59  1.96]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.423862835568355, FE: -0.09990583336916498, FEVar: 0.9359357599219975, FEATV: -0.1299159983307709, Disg: 0.31689169562536645, DisgVar: 0.19849611910887782, DisgATV: 0.0468673004456822, Var: 2.340851287844068, VarVar: 4.930380657631324e-30, VarATV: 8.002936719633454e-31}
# [nan]
# [0.74 2.42]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.4395780518365706, FE: -0.08419061710094906, FEVar: 1.0784047345059344, FEATV: -0.21539391292001647, Disg: 0.48309155723146524, DisgVar: 0.4613061011887245, DisgATV: 0.1089198707707693, Var: 2.340851287844068, VarVar: 4.930380657631324e-30, VarATV: 8.002936719633454e-31}
# [nan]
# DENI
# <numba.experimental.jitclass.boxing.DENIHybridAR object at 0x0000020C4A1AD9A0>
# Length of real time series is 82
# []
# [0.99211181 0.46098669]
# failed
# []
# [0.61 0.67]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: 1.4367526222831093, FE: -0.08701604665441054, FEVar: 1.057331098676746, FEATV: -0.2094629454269939, Disg: 2.517774306435023, DisgVar: 0.025098764314793125, DisgATV: -0.005868099369433259, Var: 2.326649033086009, VarVar: 1.597443333072549e-29, VarATV: 5.001835449770908e-30}
# [0.45 1.28 0.98 0.08]
# {InfAV: 0.0, InfVar: 0.1616161616161613, InfATV: 0.12682290484602798, Forecast: 1.2466506897945733, FE: -0.27711797914294645, FEVar: 0.9129599109963648, FEATV: -0.15981650787187657, Disg: 2.7005288681721495, DisgVar: 0.02566972822602995, DisgATV: -0.005495120681525682, Var: 0.062055594846022175, VarVar: 4.81482486096809e-35, VarATV: 4.884604931416903e-35}
# [-0.12  2.24]
# [0.99211181 0.46098669]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: 13.523398929406365, InfATV: 12.297400245740537, Forecast: nan, FE: nan, FEVar: nan, FEATV: nan, Disg: nan, DisgVar: nan, DisgATV: nan, Var: -inf, VarVar: nan, VarATV: nan}
# [nan]
# SV
# SE
# <numba.experimental.jitclass.boxing.StickyExpectationSV object at 0x0000020C47C993A0>
# Length of real time series is 4
# [0.28]
# [0.2]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 3.126091656044857, FE: 1.6023229871073377, FEVar: 6.355766365773184, FEATV: 1.6303568417367813, Disg: 0.49079101657844687, DisgVar: 0.4305434890375583, DisgATV: 0.14331557965524724, Var: 0.17707377899541113, VarVar: 0.0423870776265043, VarATV: 0.029601353819986916}
# [nan]
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 2.7517266798488174, FE: 1.2279580109112993, FEVar: 0.6527660402398924, FEATV: 0.1303008956964098, Disg: 1.0799505792475652e-27, DisgVar: 0.0, DisgATV: 0.0, Var: nan, VarVar: nan, VarATV: nan}
# [0.36]
# [0.2]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 3.1893993274142085, FE: 1.6656306584766891, FEVar: 6.672165977626938, FEATV: 1.7708274546181637, Disg: 0.32150013548771034, DisgVar: 0.21653419374436808, DisgATV: 0.05715854868906436, Var: 0.1796052957481812, VarVar: 0.04315438408070209, VarATV: 0.030259147886623556}
# [nan]
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 2.7517266798488174, FE: 1.2279580109112993, FEVar: 0.6527660402398924, FEATV: 0.1303008956964098, Disg: 1.0799505792475652e-27, DisgVar: 0.0, DisgATV: 0.0, Var: nan, VarVar: nan, VarATV: nan}
# [0.36]
# [0.2]
# Length of simulated moments is 82
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 3.1893993274142085, FE: 1.6656306584766891, FEVar: 6.672165977626938, FEATV: 1.7708274546181637, Disg: 0.32150013548771034, DisgVar: 0.21653419374436808, DisgATV: 0.05715854868906436, Var: 0.1796052957481812, VarVar: 0.04315438408070209, VarATV: 0.030259147886623556}
# [nan]
# {InfAV: 0.0, InfVar: nan, InfATV: nan, Forecast: 2.7517266798488174, FE: 1.2279580109112993, FEVar: 0.6527660402398924, FEATV: 0.1303008956964098, Disg: 1.0799505792475652e-27, DisgVar: 0.0, DisgATV: 0.0, Var: nan, VarVar: nan, VarATV: nan}
# NI
# <numba.experimental.jitclass.boxing.NoisyInformationSV object at 0x0000020C49F48F70>
# Length of real time series is 4
# []
# [0.2]
# failed
# []
# [nan]
# [0.2]
# failed
# [nan]
# [nan]
# [0.2]
# failed
# [nan]
# DE
# <numba.experimental.jitclass.boxing.DiagnosticExpectationSV object at 0x0000020C47C6FDC0>
# Length of real time series is 4
# [-0.28  0.66]
# [0.2]
# Length of simulated moments is 82
# {InfAV: nan, InfVar: nan, InfATV: nan, Forecast: 2.0552709977288544, FE: 0.5315023287913341, FEVar: 1.6531264305839826, FEATV: 0.20057197490086143, Disg: 3.769434764258837, DisgVar: 38.22739118830124, DisgATV: 5.841290047142109, Var: 0.1842151028761917, VarVar: 0.04471674119983979, VarATV: 0.030745502789244226}
# [nan]
# [-0.28  0.18]
# [0.2]
# Length of simulated moments is 82
# {InfAV: nan, InfVar: nan, InfATV: nan, Forecast: 2.04780842579466, FE: 0.5240397568571405, FEVar: 1.6368728355215654, FEATV: 0.19344429846123473, Disg: 0.2803711808126408, DisgVar: 0.2114895626154225, DisgATV: 0.032316405560993855, Var: 0.1842151028761917, VarVar: 0.04471674119983979, VarATV: 0.030745502789244226}
# [nan]
# [-0.28  0.18]
# [0.2]
# Length of simulated moments is 82
# {InfAV: nan, InfVar: nan, InfATV: nan, Forecast: 2.04780842579466, FE: 0.5240397568571405, FEVar: 1.6368728355215654, FEATV: 0.19344429846123473, Disg: 0.2803711808126408, DisgVar: 0.2114895626154225, DisgATV: 0.032316405560993855, Var: 0.1842151028761917, VarVar: 0.04471674119983979, VarATV: 0.030745502789244226}
# [nan]
# DENI
# <numba.experimental.jitclass.boxing.DENIHybridSV object at 0x0000020C49A9D040>
# Length of real time series is 4
# []
# [0.2]
# failed
# []
# [nan]
# [0.2]
# failed
# [nan]
# [nan]
# [0.2]
# failed
# [nan]

# %%
## model moments 
smm_model = pd.DataFrame(smm_list,
                         columns = list(smm_list[0].keys()),
                         index = midx)

smm_joint_model = pd.DataFrame(smm_joint_list,
                               columns = list(smm_joint_list[1].keys()),
                               index = midx)

# %%
## store times series of moments 

smm_names = ['Forecast','FE','Disg','Var']

iterables = [agents_list, process_list, ex_model_list,moments_list_general,smm_names]

midx_ts = pd.MultiIndex.from_product(iterables, names=['Agents', 'Process','Model','Moments','Variable'])

smm_ts_table = pd.DataFrame(index = midx_ts)

smm_ts_list_new = [ts[name] for ts in smm_ts_list for name in smm_names]

smm_ts_table['smm_ts'] = smm_ts_list_new

# %%
#plt.plot(realized_CPIC)
plt.plot(smm_ts_table.loc['SPF','SV','DE','FE+Disg+Var',:].loc['Disg','smm_ts'])

# %%
## data moments

smm_data_spf =  pd.DataFrame(data_moms_dct_SPF.values()).T
smm_data_spf.columns = data_moms_dct_SPF.keys()

smm_data_sce =  pd.DataFrame(data_moms_dct_SCE.values()).T
smm_data_sce.columns = data_moms_dct_SCE.keys()

# %%
mom_compare_spf = smm_data_spf.append(smm_model.loc['SPF'])
mom_compare_sce = smm_data_sce.append(smm_model.loc['SCE'])

mom_joint_compare_spf = smm_data_spf.append(smm_joint_model.loc['SPF','AR'])
mom_joint_compare_sce = smm_data_sce.append(smm_joint_model.loc['SCE','AR'])
# Out:
# C:\Users\want\AppData\Local\Temp\ipykernel_18284\835143023.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mom_compare_spf = smm_data_spf.append(smm_model.loc['SPF'])
# C:\Users\want\AppData\Local\Temp\ipykernel_18284\835143023.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mom_compare_sce = smm_data_sce.append(smm_model.loc['SCE'])
# C:\Users\want\AppData\Local\Temp\ipykernel_18284\835143023.py:4: PerformanceWarning: indexing past lexsort depth may impact performance.
#   mom_joint_compare_spf = smm_data_spf.append(smm_joint_model.loc['SPF','AR'])
# C:\Users\want\AppData\Local\Temp\ipykernel_18284\835143023.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mom_joint_compare_spf = smm_data_spf.append(smm_joint_model.loc['SPF','AR'])
# C:\Users\want\AppData\Local\Temp\ipykernel_18284\835143023.py:5: PerformanceWarning: indexing past lexsort depth may impact performance.
#   mom_joint_compare_sce = smm_data_sce.append(smm_joint_model.loc['SCE','AR'])
# C:\Users\want\AppData\Local\Temp\ipykernel_18284\835143023.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mom_joint_compare_sce = smm_data_sce.append(smm_joint_model.loc['SCE','AR'])

# %%
## export 
mom_compare_spf.to_excel('./tables/after2022/spf_moments.xlsx')
mom_compare_sce.to_excel('./tables/after2022/sce_moments.xlsx')
mom_joint_compare_spf.to_excel('./tables/after2022/spf_joint_est_moments.xlsx')
mom_joint_compare_sce.to_excel('./tables/after2022/sce_joint_est_moments.xlsx')

# %%
mom_compare_spf
# Out:
#                          InfAV  InfVar  InfATV   FE  FEVar  FEATV  Disg  \
# 0                         0.00    0.17   -0.04 0.12   0.14  -0.05  0.16
# (AR, SE, FE)              0.00    0.00    0.00 0.20   0.17    NaN  0.04
# (AR, SE, FE+Disg)         0.00    0.00    0.00 0.19   0.17    NaN  0.04
# (AR, SE, FE+Disg+Var)     0.00    0.00    0.00 0.21   0.18    NaN  0.03
# (AR, NI, FE)               NaN     NaN     NaN  NaN    NaN    NaN   NaN
# (AR, NI, FE+Disg)         0.00    0.00    0.00 0.24   0.19    NaN  0.00
# (AR, NI, FE+Disg+Var)     0.00    0.00    0.00 0.24   0.19    NaN  0.00
# (AR, DE, FE)              0.00    0.00    0.00 0.24   0.19    NaN  0.01
# (AR, DE, FE+Disg)         0.00    0.00    0.00 0.24   0.20    NaN  0.18
# (AR, DE, FE+Disg+Var)     0.00    0.00    0.00 0.24   0.20    NaN  0.18
# (AR, DENI, FE)             NaN     NaN     NaN  NaN    NaN    NaN   NaN
# (AR, DENI, FE+Disg)       0.00    0.00    0.00 0.24   0.19    NaN  0.20
# (AR, DENI, FE+Disg+Var)   0.00    0.00    0.00 0.23   0.16    NaN  0.34
# (SV, SE, FE)              0.00     NaN     NaN 1.49   1.72    NaN  1.32
# (SV, SE, FE+Disg)         0.00     NaN     NaN 1.61   1.98    NaN  1.16
# (SV, SE, FE+Disg+Var)     0.00     NaN     NaN 1.58   1.90    NaN  1.22
# (SV, NI, FE)               NaN     NaN     NaN  NaN    NaN    NaN   NaN
# (SV, NI, FE+Disg)          NaN     NaN     NaN 0.23   0.19    NaN  0.00
# (SV, NI, FE+Disg+Var)      NaN     NaN     NaN 0.23   0.19    NaN  0.00
# (SV, DE, FE)               NaN     NaN     NaN 0.14   0.21    NaN  1.60
# (SV, DE, FE+Disg)          NaN     NaN     NaN 0.13   0.21    NaN  0.16
# (SV, DE, FE+Disg+Var)      NaN     NaN     NaN 0.13   0.21    NaN  0.16
# (SV, DENI, FE)             NaN     NaN     NaN  NaN    NaN    NaN   NaN
# (SV, DENI, FE+Disg)       0.00     NaN     NaN 0.24   0.17    NaN  0.00
# (SV, DENI, FE+Disg+Var)   0.00     NaN     NaN 0.24   0.18    NaN  0.00
#
#                          DisgVar  DisgATV  Var  VarVar  VarATV  Forecast
# 0                           0.02     0.01 0.21    0.00    0.00       NaN
# (AR, SE, FE)                0.00      NaN 2.91    0.00     NaN      2.04
# (AR, SE, FE+Disg)           0.00      NaN 2.93    0.00     NaN      2.04
# (AR, SE, FE+Disg+Var)       0.00      NaN 2.71    0.00     NaN      2.05
# (AR, NI, FE)                 NaN      NaN  NaN     NaN     NaN       NaN
# (AR, NI, FE+Disg)           0.00      NaN 2.37    0.00     NaN      2.09
# (AR, NI, FE+Disg+Var)       0.00      NaN 2.37    0.00     NaN      2.09
# (AR, DE, FE)                0.00      NaN 2.37    0.00     NaN      2.08
# (AR, DE, FE+Disg)           0.05      NaN 2.37    0.00     NaN      2.08
# (AR, DE, FE+Disg+Var)       0.05      NaN 2.37    0.00     NaN      2.08
# (AR, DENI, FE)               NaN      NaN  NaN     NaN     NaN       NaN
# (AR, DENI, FE+Disg)         0.00      NaN 2.37    0.00     NaN      2.08
# (AR, DENI, FE+Disg+Var)     0.00      NaN 2.37    0.00     NaN      2.08
# (SV, SE, FE)                1.30      NaN 0.34    0.05     NaN      3.34
# (SV, SE, FE+Disg)           1.00      NaN 0.36    0.05     NaN      3.45
# (SV, SE, FE+Disg+Var)       1.08      NaN 0.36    0.05     NaN      3.42
# (SV, NI, FE)                 NaN      NaN  NaN     NaN     NaN       NaN
# (SV, NI, FE+Disg)           0.00      NaN 0.45    0.05     NaN      2.07
# (SV, NI, FE+Disg+Var)       0.00      NaN 0.45    0.05     NaN      2.07
# (SV, DE, FE)                3.28      NaN 0.45    0.05     NaN      1.98
# (SV, DE, FE+Disg)           0.03      NaN 0.45    0.05     NaN      1.97
# (SV, DE, FE+Disg+Var)       0.03      NaN 0.45    0.05     NaN      1.97
# (SV, DENI, FE)               NaN      NaN  NaN     NaN     NaN       NaN
# (SV, DENI, FE+Disg)         0.00      NaN 0.45    0.05     NaN      2.08
# (SV, DENI, FE+Disg+Var)     0.00      NaN 0.45    0.05     NaN      2.09

# %%
mom_joint_compare_spf
# Out:
#                      InfAV  InfVar  InfATV    FE  FEVar  FEATV  Disg  DisgVar  \
# 0                     0.00    0.17   -0.04  0.12   0.14  -0.05  0.16     0.02
# (SE, FE)              0.00    0.00    0.00  0.18   0.17    NaN  0.04     0.00
# (SE, FE+Disg)         0.00    0.25    0.20 -0.36   0.17    NaN  0.05     0.00
# (SE, FE+Disg+Var)     0.00    0.25    0.20 -0.36   0.17    NaN  0.05     0.00
# (NI, FE)               NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (NI, FE+Disg)         0.00    0.08    0.07 -0.01   0.18    NaN  0.00     0.00
# (NI, FE+Disg+Var)     0.00    0.13    0.11 -0.01   0.18    NaN  0.00     0.00
# (DE, FE)              0.00    0.06    0.05 -0.19   0.18    NaN  0.00     0.00
# (DE, FE+Disg)         0.00    0.06    0.05 -0.19   0.18    NaN  0.12     0.02
# (DE, FE+Disg+Var)      NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (DENI, FE)             NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (DENI, FE+Disg)        NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (DENI, FE+Disg+Var)    NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
#
#                      DisgATV  Var  VarVar  VarATV  Forecast
# 0                       0.01 0.21    0.00    0.00       NaN
# (SE, FE)                 NaN 0.01    0.00     NaN      2.02
# (SE, FE+Disg)            NaN 0.12    0.00     NaN      1.48
# (SE, FE+Disg+Var)        NaN 0.12    0.00     NaN      1.48
# (NI, FE)                 NaN  NaN     NaN     NaN       NaN
# (NI, FE+Disg)            NaN 0.02    0.00     NaN      1.84
# (NI, FE+Disg+Var)        NaN 0.03    0.00     NaN      1.84
# (DE, FE)                 NaN 0.02    0.00     NaN      1.66
# (DE, FE+Disg)            NaN 0.02    0.00     NaN      1.66
# (DE, FE+Disg+Var)        NaN  NaN     NaN     NaN       NaN
# (DENI, FE)               NaN  NaN     NaN     NaN       NaN
# (DENI, FE+Disg)          NaN  NaN     NaN     NaN       NaN
# (DENI, FE+Disg+Var)      NaN  NaN     NaN     NaN       NaN

# %%
mom_compare_sce
# Out:
#                          InfAV  InfVar  InfATV    FE  FEVar  FEATV  Disg  \
# 0                         0.00    0.65    0.61  1.81   0.93   0.89  2.81
# (AR, SE, FE)              0.00   13.52   12.30 -0.12   0.88  -0.08  0.09
# (AR, SE, FE+Disg)         0.00   13.52   12.30 -0.12   0.88  -0.08  0.09
# (AR, SE, FE+Disg+Var)     0.00   13.52   12.30 -0.12   0.88  -0.08  0.09
# (AR, NI, FE)               NaN     NaN     NaN   NaN    NaN    NaN   NaN
# (AR, NI, FE+Disg)         0.00   13.52   12.30 -0.10   1.31  -0.02  0.04
# (AR, NI, FE+Disg+Var)     0.00   13.52   12.30 -0.10   1.31  -0.02  0.04
# (AR, DE, FE)              0.00   13.52   12.30 -0.10   0.94  -0.13  0.05
# (AR, DE, FE+Disg)         0.00   13.52   12.30 -0.10   0.94  -0.13  0.32
# (AR, DE, FE+Disg+Var)     0.00   13.52   12.30 -0.08   1.08  -0.22  0.48
# (AR, DENI, FE)             NaN     NaN     NaN   NaN    NaN    NaN   NaN
# (AR, DENI, FE+Disg)       0.00   13.52   12.30 -0.09   1.06  -0.21  2.52
# (AR, DENI, FE+Disg+Var)   0.00   13.52   12.30   NaN    NaN    NaN   NaN
# (SV, SE, FE)              0.00     NaN     NaN  1.60   6.36   1.63  0.49
# (SV, SE, FE+Disg)         0.00     NaN     NaN  1.67   6.67   1.77  0.32
# (SV, SE, FE+Disg+Var)     0.00     NaN     NaN  1.67   6.67   1.77  0.32
# (SV, NI, FE)               NaN     NaN     NaN   NaN    NaN    NaN   NaN
# (SV, NI, FE+Disg)          NaN     NaN     NaN   NaN    NaN    NaN   NaN
# (SV, NI, FE+Disg+Var)      NaN     NaN     NaN   NaN    NaN    NaN   NaN
# (SV, DE, FE)               NaN     NaN     NaN  0.53   1.65   0.20  3.77
# (SV, DE, FE+Disg)          NaN     NaN     NaN  0.52   1.64   0.19  0.28
# (SV, DE, FE+Disg+Var)      NaN     NaN     NaN  0.52   1.64   0.19  0.28
# (SV, DENI, FE)             NaN     NaN     NaN   NaN    NaN    NaN   NaN
# (SV, DENI, FE+Disg)        NaN     NaN     NaN   NaN    NaN    NaN   NaN
# (SV, DENI, FE+Disg+Var)    NaN     NaN     NaN   NaN    NaN    NaN   NaN
#
#                          DisgVar  DisgATV  Var  VarVar  VarATV  Forecast
# 0                           0.09     0.03 1.75    0.03    0.00       NaN
# (AR, SE, FE)                0.01     0.00 2.64    0.00    0.00      1.40
# (AR, SE, FE+Disg)           0.01     0.00 2.64    0.00    0.00      1.40
# (AR, SE, FE+Disg+Var)       0.01     0.00 2.64    0.00    0.00      1.40
# (AR, NI, FE)                 NaN      NaN  NaN     NaN     NaN       NaN
# (AR, NI, FE+Disg)           0.00    -0.00 2.72    0.00    0.00      1.42
# (AR, NI, FE+Disg+Var)       0.00    -0.00 2.73    0.00    0.00      1.42
# (AR, DE, FE)                0.01     0.00 2.34    0.00    0.00      1.42
# (AR, DE, FE+Disg)           0.20     0.05 2.34    0.00    0.00      1.42
# (AR, DE, FE+Disg+Var)       0.46     0.11 2.34    0.00    0.00      1.44
# (AR, DENI, FE)               NaN      NaN  NaN     NaN     NaN       NaN
# (AR, DENI, FE+Disg)         0.03    -0.01 2.33    0.00    0.00      1.44
# (AR, DENI, FE+Disg+Var)      NaN      NaN -inf     NaN     NaN       NaN
# (SV, SE, FE)                0.43     0.14 0.18    0.04    0.03      3.13
# (SV, SE, FE+Disg)           0.22     0.06 0.18    0.04    0.03      3.19
# (SV, SE, FE+Disg+Var)       0.22     0.06 0.18    0.04    0.03      3.19
# (SV, NI, FE)                 NaN      NaN  NaN     NaN     NaN       NaN
# (SV, NI, FE+Disg)            NaN      NaN  NaN     NaN     NaN       NaN
# (SV, NI, FE+Disg+Var)        NaN      NaN  NaN     NaN     NaN       NaN
# (SV, DE, FE)               38.23     5.84 0.18    0.04    0.03      2.06
# (SV, DE, FE+Disg)           0.21     0.03 0.18    0.04    0.03      2.05
# (SV, DE, FE+Disg+Var)       0.21     0.03 0.18    0.04    0.03      2.05
# (SV, DENI, FE)               NaN      NaN  NaN     NaN     NaN       NaN
# (SV, DENI, FE+Disg)          NaN      NaN  NaN     NaN     NaN       NaN
# (SV, DENI, FE+Disg+Var)      NaN      NaN  NaN     NaN     NaN       NaN

# %%
mom_joint_compare_sce
# Out:
#                      InfAV  InfVar  InfATV    FE  FEVar  FEATV  Disg  DisgVar  \
# 0                     0.00    0.65    0.61  1.81   0.93   0.89  2.81     0.09
# (SE, FE)              0.00    0.00    0.00  0.03   0.93   0.03  0.23     0.02
# (SE, FE+Disg)         0.00    0.25    0.20 -0.39   0.77  -0.00  0.11     0.01
# (SE, FE+Disg+Var)     0.00    0.25    0.20 -0.39   0.77  -0.00  0.11     0.01
# (NI, FE)               NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (NI, FE+Disg)         0.00    0.00    0.00  0.91   0.79   0.23  0.00     0.00
# (NI, FE+Disg+Var)      NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (DE, FE)              0.00    0.41    0.36 -0.14   0.92  -0.12  0.01     0.00
# (DE, FE+Disg)          NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (DE, FE+Disg+Var)      NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (DENI, FE)             NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
# (DENI, FE+Disg)       0.00    0.16    0.13 -0.28   0.91  -0.16  2.70     0.03
# (DENI, FE+Disg+Var)    NaN     NaN     NaN   NaN    NaN    NaN   NaN      NaN
#
#                      DisgATV  Var  VarVar  VarATV  Forecast
# 0                       0.03 1.75    0.03    0.00       NaN
# (SE, FE)               -0.00 0.01    0.00    0.00      1.55
# (SE, FE+Disg)          -0.00 0.12    0.00    0.00      1.13
# (SE, FE+Disg+Var)      -0.00 0.12    0.00    0.00      1.13
# (NI, FE)                 NaN  NaN     NaN     NaN       NaN
# (NI, FE+Disg)           0.00 0.02    0.00    0.00      2.43
# (NI, FE+Disg+Var)        NaN  NaN     NaN     NaN       NaN
# (DE, FE)                0.00 0.09    0.00    0.00      1.39
# (DE, FE+Disg)            NaN  NaN     NaN     NaN       NaN
# (DE, FE+Disg+Var)        NaN  NaN     NaN     NaN       NaN
# (DENI, FE)               NaN  NaN     NaN     NaN       NaN
# (DENI, FE+Disg)        -0.01 0.06    0.00    0.00      1.25
# (DENI, FE+Disg+Var)      NaN  NaN     NaN     NaN       NaN
