# %%
import matplotlib.pyplot as plt
import joypy
from matplotlib import cm
import pandas as pd
import numpy as np

# %%
## import data 

SPFQ = pd.read_stata('../SurveyData/SPF/individual/InfExpSPFPointIndQ.dta')
SCEM = pd.read_stata('../../../InfVar-Local/workingfolder/SurveyData/SCE/InfExpSCEProbIndM.dta')

# %%
SPFQ
# Out:
#           dateQ    year  quarter  month     ID INDUSTRY  PCE1    PCE2    PCE3  \
# 0    1968-10-01  1968.0      4.0    9.0    1.0     #N/A   NaN     NaN     NaN
# 1    1969-04-01  1969.0      2.0    4.0    1.0     #N/A   NaN     NaN     NaN
# 2    1969-07-01  1969.0      3.0    7.0    1.0     #N/A   NaN     NaN     NaN
# 3    1969-10-01  1969.0      4.0    9.0    1.0     #N/A   NaN     NaN     NaN
# 4    1970-01-01  1970.0      1.0    1.0    1.0     #N/A   NaN     NaN     NaN
# ...         ...     ...      ...    ...    ...      ...   ...     ...     ...
# 8673 2022-04-01  2022.0      2.0    4.0  593.0        2   7.0  5.5222  5.2154
# 8674 2021-10-01  2021.0      4.0    9.0  594.0        2   NaN     NaN     NaN
# 8675 2022-01-01  2022.0      1.0    1.0  594.0        2   NaN     NaN     NaN
# 8676 2022-04-01  2022.0      2.0    4.0  594.0        2   NaN     NaN     NaN
# 8677        NaT     NaN      NaN    NaN    NaN            NaN     NaN     NaN
#
# ...

# %%
## create labels for year 
labels_SPF =[y for y in list(SPFQ.year.unique())] 
labels_SCE=[y for y in list(SCEM.year.unique())]

# %%
## SCE 
labels_SCE_list = ['Expected inflation',
              'Uncertainty']

mom_SCE_list = ['Q9_mean',
           'Q9_var']

## SPF
#labels_SPF_list = ['Expected inflation',
#              'Uncertainty']

#mom_SPF_list = ['Q9_mean',
#           'Q9_var']

# %%
## plot the cross-sectional over time 

for mom_id,mom in enumerate(mom_list):
    ## exclude outliers 
    #mom_nonan = SCEM[mom].dropna()
    #mom_lb, mom_ub = np.percentile(mom_nonan,5),np.percentile(mom_nonan,95) ## exclude top and bottom 3% observations
    #print(mom_lb)
    #print(mom_ub)
    #to_keep = (mom_nonan < mom_ub) & (mom_nonan > mom_lb) & (mom_nonan!=0)
    #print(to_keep.shape)
    #to_plot = mom_nonan[to_keep]
    fig, axes = joypy.joyplot(SCEM, 
                              by="year", 
                              column= mom, 
                              labels=labels, 
                              kind="kde", 
                              range_style='own', 
                              grid="y", 
                              linewidth=1, 
                              legend=False, 
                              figsize=(6,7),
                              title=labels_list[mom_id],
                              colormap=cm.summer
                             )
    plt.savefig('../graphs/ind/joy_'+str(mom)+'.jpg')
